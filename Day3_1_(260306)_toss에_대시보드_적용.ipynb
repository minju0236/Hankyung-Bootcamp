# %% [markdown]
# <a href="https://colab.research.google.com/github/minju0236/Hankyung-Bootcamp/blob/main/Day3_1_(260306)_toss%EC%97%90_%EB%8C%80%EC%8B%9C%EB%B3%B4%EB%93%9C_%EC%A0%81%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !npm init -y
# !npm install express
# Out:
# Wrote to /content/package.json:
#
# {
#   "name": "content",
#   "version": "1.0.0",
#   "main": "server.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1",
#     "start": "node server.js"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "dependencies": {
#     "express": "^5.2.1"
#   },
#   "devDependencies": {},
#   "description": ""
# }
#
#
#
# ⠙⠙⠹⠸⠼⠴⠦
# up to date, audited 66 packages in 1s
# ⠦
# ⠦22 packages are looking for funding
# ⠦  run `npm fund` for details
# ⠦
# found 0 vulnerabilities
# ⠦

# %%
# %%writefile server.js
#
# const express = require("express");
# const path = require("path");
# const app = express();
#
# const TEMPLATE_PATH = path.join(__dirname, "templates");
#
# // templates 안의 js 파일 접근 가능
# app.use(express.static(path.join(__dirname, "templates")));
#
# // static 폴더 전체 열기
# app.use(express.static(path.join(__dirname, "static")));
#
# // img 폴더도 /img 경로로 접근 가능
# app.use("/img", express.static(path.join(__dirname, "static", "img")));
#
# // Home
# app.get("/", (req, res) => {
#   res.sendFile(path.join(TEMPLATE_PATH, "index.html"));
# });
#
# // About
# app.get("/about", (req, res) => {
#   res.sendFile(path.join(TEMPLATE_PATH, "about.html"));
# });
#
# // Products
# app.get("/products", (req, res) => {
#   res.sendFile(path.join(TEMPLATE_PATH, "products.html"));
# });
#
# // Loan
# app.get("/loan", (req, res) => {
#   res.sendFile(path.join(TEMPLATE_PATH, "loan.html"));
# });
#
# // Support
# app.get("/support", (req, res) => {
#   res.sendFile(path.join(TEMPLATE_PATH, "support.html"));
# });
#
# app.listen(3000, () => {
#   console.log("Server running on port 3000");
# });
# Out:
# Overwriting server.js

# %%
# !nohup node server.js > server.log 2>&1 &

# %%
# !tail -n 20 server.log

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# changed 1 package in 3s
# ⠸

# %%
# !nohup cloudflared tunnel --url http://localhost:3000 > tunnel.log 2>&1 &

# %%
# !tail -n 20 tunnel.log

# %%
# !grep -o "https://[a-zA-Z0-9.-]*\.trycloudflare.com" tunnel.log |tail -n 1
# Out:
# https://debate-protest-wallpapers-acid.trycloudflare.com
