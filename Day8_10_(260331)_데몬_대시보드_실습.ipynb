# %% [markdown]
# <a href="https://colab.research.google.com/github/minju0236/Hankyung-Bootcamp/blob/main/Day8_10_(260331)_%EB%8D%B0%EB%AA%AC_%EB%8C%80%EC%8B%9C%EB%B3%B4%EB%93%9C_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !npm install express mysql2
# Out:
# ⠙⠹⠸⠼⠴
# up to date, audited 77 packages in 1s
# ⠴
# ⠴24 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !npm install express mysql2
# Out:
# ⠙⠹⠸⠼⠴
# up to date, audited 77 packages in 1s
# ⠴
# ⠴24 packages are looking for funding
# ⠴  run `npm fund` for details
# ⠴
# found 0 vulnerabilities
# ⠴

# %%
# !nohup node server.js > server.log 2>&1 &

# %%
# !nohup node daemon.js > daemon.log 2>&1 &

# %%
# !nohup cloudflared tunnel --url http://localhost:3000 > tunnel.log 2>&1 &

# %%
# !tail -n 20 tunnel.log
# Out:
# 2026-03-31T06:32:46Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-03-31T06:32:50Z INF +--------------------------------------------------------------------------------------------+
# 2026-03-31T06:32:50Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-03-31T06:32:50Z INF |  https://retirement-graduate-vbulletin-importantly.trycloudflare.com                       |
# 2026-03-31T06:32:50Z INF +--------------------------------------------------------------------------------------------+
# 2026-03-31T06:32:50Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-03-31T06:32:50Z INF Version 2026.3.0 (Checksum 4a9e50e6d6d798e90fcd01933151a90bf7edd99a0a55c28ad18f2e16263a5c30)
# 2026-03-31T06:32:50Z INF GOOS: linux, GOVersion: go1.24.13, GoArch: amd64
# ...
