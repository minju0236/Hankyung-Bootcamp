# %% [markdown]
# <a href="https://colab.research.google.com/github/minju0236/Hankyung-Bootcamp/blob/main/Day1_a_(260326)_%EB%8B%A8%EC%9D%BC_%EC%9D%B4%EC%A4%91_%EC%97%B0%EA%B2%B0_%EB%A6%AC%EC%8A%A4%ED%8A%B8_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile node.js
#
# // [단계 1] 노드 생성 함수 정의
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# // [단계 2] 리스트 초기 상태 설정
# let list = {
#   head: null,
#   size: 0
# };
#
# // [단계 3] 초기 상태 출력 확인
# console.log("--- [초기화 상태] ---");
# console.log("리스트 객체:", list);
# console.log("Head 연결 여부:", list.head === null ? "비어 있음" : "연결됨");
# console.log("현재 크기:", list.size);
# Out:
# Writing node.js

# %%
# !node node.js
# Out:
# --- [초기화 상태] ---
# 리스트 객체: { head: null, size: 0 }
# Head 연결 여부: 비어 있음
# 현재 크기: 0

# %%
# %%writefile node.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# // [실행 전] 초기 상태: { head: null, size: 0 }
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
#
#   console.log(`[prepend] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
#
# // 실행 예시 및 출력
# prepend(list, "데이터1");
# // 출력: { "head": { "data": "데이터1", "next": null }, "size": 1 }
#
# prepend(list, "데이터2");
# // 출력: { "head": { "data": "데이터2", "next": { "data": "데이터1", "next": null } }, "size": 2 }
# Out:
# Overwriting node.js

# %%
# !node node.js
# Out:
# [prepend] '데이터1' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터1",
#     "next": null
#   },
#   "size": 1
# }
# [prepend] '데이터2' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": null
#     }
#   },
#   "size": 2
# }

# %% [markdown]
# 스택:LIFO구조로, 처음 넣은 데이터가 가장 마지막에 나오는 형태이다. 가볍고 작음.
#
# 힙:런타임에 동적 메모리를 저장하는 공간이다. 스택보다 큼.
#
# 단일연결리스트: 노드가 한 방향으로 연결되어 있는 형태로, 값을 가진 데이터와 주소를 가진 포인터(next)로 이루어져 있다.

# %%
# %%writefile node.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# // [실행 전] 초기 상태: { head: null, size: 0 }
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
#
#   console.log(`[prepend] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
#
# // 실행 예시 및 출력
# prepend(list, "데이터1");
# // 출력: { "head": { "data": "데이터1", "next": null }, "size": 1 }
#
# prepend(list, "데이터2");
# // 출력: { "head": { "data": "데이터2", "next": { "data": "데이터1", "next": null } }, "size": 2 }
#
# // [실행 전] 초기 상태: { head: { data: '데이터2', next: { data: '데이터1', next: null } }, size: 2 }
# function append(list, data) {
#   const newNode = createNode(data);
#   if (!list.head) {
#     list.head = newNode;
#   } else {
#     let current = list.head;
#     while (current.next) { current = current.next; } // 끝까지 이동
#     current.next = newNode;
#   }
#   list.size++;
#
#   console.log(`[append] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
#
# // 실행 예시 및 출력
# append(list, "데이터3");
# /* 출력: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": {
#         "data": "데이터3",
#         "next": null
#       }
#     }
#   },
#   "size": 3
# }
# */
# Out:
# Overwriting node.js

# %%
# !node node.js
# Out:
# [prepend] '데이터1' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터1",
#     "next": null
#   },
#   "size": 1
# }
# [prepend] '데이터2' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": null
#     }
#   },
#   "size": 2
# }
# [append] '데이터3' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": {
#         "data": "데이터3",
#         "next": null
#       }
#     }
#   },
#   "size": 3
# }

# %%
# %%writefile node.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# // [실행 전] 초기 상태: { head: null, size: 0 }
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
#
#   console.log(`[prepend] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
#
# // 실행 예시 및 출력
# prepend(list, "데이터1");
# // 출력: { "head": { "data": "데이터1", "next": null }, "size": 1 }
#
# prepend(list, "데이터2");
# // 출력: { "head": { "data": "데이터2", "next": { "data": "데이터1", "next": null } }, "size": 2 }
#
# // [실행 전] 초기 상태: { head: { data: '데이터2', next: { data: '데이터1', next: null } }, size: 2 }
# function append(list, data) {
#   const newNode = createNode(data);
#   if (!list.head) {
#     list.head = newNode;
#   } else {
#     let current = list.head;
#     while (current.next) { current = current.next; } // 끝까지 이동
#     current.next = newNode;
#   }
#   list.size++;
#
#   console.log(`[append] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
#
# // 실행 예시 및 출력
# append(list, "데이터3");
#
# // [실행 전] 초기 상태: { "head": { "data": "데이터2", "next": { "data": "데이터1", "next": { "data": "데이터3", "next": null } } }, "size": 3 }
# function remove(list, data) {
#   if (!list.head) return;
#
#   if (list.head.data === data) {
#     list.head = list.head.next; // 첫 번째 노드 건너뛰기
#     list.size--;
#     console.log(`[remove] Head 노드 '${data}' 삭제 후 리스트 상태:`, JSON.stringify(list, null, 2));
#     return;
#   }
#
#   let curr = list.head;
#   while (curr.next && curr.next.data !== data) { curr = curr.next; }
#
#   if (curr.next) {
#     curr.next = curr.next.next; // 참조 연결 끊기
#     list.size--;
#     console.log(`[remove] 중간/끝 노드 '${data}' 삭제 후 리스트 상태:`, JSON.stringify(list, null, 2));
#   } else {
#     console.log(`[remove 실패] '${data}'를 찾을 수 없습니다.`);
#   }
# }
#
# // 실행 예시 및 출력
# remove(list, "데이터1");
# /* 출력: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터3",
#       "next": null
#     }
#   },
#   "size": 2
# }
# */
# Out:
# Overwriting node.js

# %%
# !node node.js
# Out:
# [prepend] '데이터1' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터1",
#     "next": null
#   },
#   "size": 1
# }
# [prepend] '데이터2' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": null
#     }
#   },
#   "size": 2
# }
# [append] '데이터3' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": {
#         "data": "데이터3",
#         "next": null
#       }
#     }
#   },
#   "size": 3
# }
# [remove] 중간/끝 노드 '데이터1' 삭제 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터3",
#       "next": null
#     }
#   },
#   "size": 2
# }

# %%
# %%writefile node.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head;
#   list.head = newNode;
#   list.size++;
#
#   console.log(`[prepend] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
#
# prepend(list, "데이터1");
# prepend(list, "데이터2");
# prepend(list, "데이터3");
#
# function remove(list, data) {
#   if (!list.head) return;
#
#   if (list.head.data === data) {
#     list.head = list.head.next; // 첫 번째 노드 건너뛰기
#     list.size--;
#     console.log(`[remove] Head 노드 '${data}' 삭제 후 리스트 상태:`, JSON.stringify(list, null, 2));
#     return;
#   }
#
#   let curr = list.head;
#   while (curr.next && curr.next.data !== data) { curr = curr.next; }
#
#   if (curr.next) {
#     curr.next = curr.next.next; // 참조 연결 끊기
#     list.size--;
#     console.log(`[remove] '${data}' 삭제 후 리스트 상태:`, JSON.stringify(list, null, 2));
#   } else {
#     console.log(`[remove 실패] '${data}'를 찾을 수 없습니다.`);
#   }
# }
#
# remove(list, "데이터2");
# Out:
# Overwriting node.js

# %%
# !node node.js
# Out:
# [prepend] '데이터1' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터1",
#     "next": null
#   },
#   "size": 1
# }
# [prepend] '데이터2' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터2",
#     "next": {
#       "data": "데이터1",
#       "next": null
#     }
#   },
#   "size": 2
# }
# [prepend] '데이터3' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "데이터3",
#     "next": {
#       "data": "데이터2",
#       "next": {
#         "data": "데이터1",
#         "next": null
#       }
#     }
#   },
#   "size": 3
# }
# [remove] '데이터2' 삭제 후 리스트 상태: {
#   "head": {
#     "data": "데이터3",
#     "next": {
#       "data": "데이터1",
#       "next": null
#     }
#   },
#   "size": 2
# }

# %%
# %%writefile doubleNode.js
#
# // [실행 전] 이중 연결 리스트 초기 리스트: { head: null, tail: null, size: 0 }
#
# const createDoublyNode = (data) => ({
#   data,
#   prev: null, // 이전 노드 참조 추가
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# // 이중 연결 리스트 삽입 예시 (가장 앞)
# function prependDoubly(list, data) {
#   const newNode = createDoublyNode(data);
#
#   if (!list.head) {
#     list.head = newNode;
#     list.tail = newNode; // 노드가 하나면 head이자 tail
#   } else {
#     newNode.next = list.head;
#     list.head.prev = newNode; // 기존 head의 이전 노드로 새 노드 지정
#     list.head = newNode;
#   }
#   list.size++;
#
#   console.log(`[Doubly-Prepend] '${data}' 삽입 후 상태:`, JSON.stringify(list, null, 2));
# }
#
# // 실행 예시 및 출력
# prependDoubly(list, "이중데이터1");
# /* 출력: {
#   "head": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   },
#   "tail": { ... 동일 노드 참조 ... },
#   "size": 1
# }
# */
#
# const arr = [];
#
# console.time('Array unshift'); // 타이머 시작
#
# for (let i = 0; i < 100000; i++) {
#   arr.unshift(i); // 기존 인덱스 10만 개를 매번 뒤로 밀어냄 (O(n))
# }
#
# console.timeEnd('Array unshift');
# Out:
# Overwriting doubleNode.js

# %%
# !node doubleNode.js
# Out:
# [Doubly-Prepend] '이중데이터1' 삽입 후 상태: {
#   "head": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   },
#   "size": 1,
#   "tail": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   }
# }
# Array unshift: 847.138ms

# %%
# %%writefile doubleNode.js
#
# // [실행 전] 이중 연결 리스트 초기 리스트: { head: null, tail: null, size: 0 }
#
# const createDoublyNode = (data) => ({
#   data,
#   prev: null, // 이전 노드 참조 추가
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# // 이중 연결 리스트 삽입 예시 (가장 앞)
# function prependDoubly(list, data) {
#   const newNode = createDoublyNode(data);
#
#   if (!list.head) {
#     list.head = newNode;
#     list.tail = newNode; // 노드가 하나면 head이자 tail
#   } else {
#     newNode.next = list.head;
#     list.head.prev = newNode; // 기존 head의 이전 노드로 새 노드 지정
#     list.head = newNode;
#   }
#   list.size++;
#
#   console.log(`[Doubly-Prepend] '${data}' 삽입 후 상태:`, JSON.stringify(list, null, 2));
# }
#
# prependDoubly(list, "이중데이터1");
#
# const nodeA = createDoublyNode("nodeA");
# const nodeB = createDoublyNode("nodeB");
#
# // [실행 전] 상황: nodeA <-> nodeB (연결된 상태)
# function insertBetween(nodeA, nodeB, data) {
#   const newNode = createDoublyNode(data);
#
#   // A와 B 사이에 NEW를 넣는 핵심 로직
#   newNode.next = nodeB;   // 1. 새 노드의 다음을 B로
#   newNode.prev = nodeA;   // 2. 새 노드의 이전을 A로
#   nodeA.next = newNode;   // 3. A의 다음을 새 노드로
#   nodeB.prev = newNode;   // 4. B의 이전을 새 노드로
#
#   console.log(`[InsertBetween] '${nodeA.data}'와 '${nodeB.data}' 사이에 '${data}' 삽입 완료`);
#   console.log(`결과 구조: ${nodeA.data} <-> ${newNode.data} <-> ${nodeB.data}`);
# }
#
# // 실행 예시 및 출력
# // (nodeA: "데이터1", nodeB: "데이터2"가 있다고 가정)
# insertBetween(nodeA, nodeB, "NEW");
#
# /* 출력:
# [InsertBetween] '데이터1'와 '데이터2' 사이에 'NEW' 삽입 완료
# 결과 구조: 데이터1 <-> NEW <-> 데이터2
# */
# Out:
# Overwriting doubleNode.js

# %%
# !node doubleNode.js
# Out:
# [Doubly-Prepend] '이중데이터1' 삽입 후 상태: {
#   "head": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   },
#   "size": 1,
#   "tail": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   }
# }
# [InsertBetween] 'nodeA'와 'nodeB' 사이에 'NEW' 삽입 완료
# 결과 구조: nodeA <-> NEW <-> nodeB

# %%
# %%writefile doubleNode.js
#
# // [실행 전] 이중 연결 리스트 초기 리스트: { head: null, tail: null, size: 0 }
#
# const createDoublyNode = (data) => ({
#   data,
#   prev: null, // 이전 노드 참조 추가
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# // 이중 연결 리스트 삽입 예시 (가장 앞)
# function prependDoubly(list, data) {
#   const newNode = createDoublyNode(data);
#
#   if (!list.head) {
#     list.head = newNode;
#     list.tail = newNode; // 노드가 하나면 head이자 tail
#   } else {
#     newNode.next = list.head;
#     list.head.prev = newNode; // 기존 head의 이전 노드로 새 노드 지정
#     list.head = newNode;
#   }
#   list.size++;
#
#   console.log(`[Doubly-Prepend] '${data}' 삽입 후 상태:`, JSON.stringify(list, null, 2));
# }
#
# prependDoubly(list, "이중데이터1");
#
#
# const nodeA = createDoublyNode("nodeA");
# const nodeB = createDoublyNode("nodeB");
#
# // [실행 전] 상황: nodeA <-> nodeB (연결된 상태)
# function insertBetween(nodeA, nodeB, data) {
#   const newNode = createDoublyNode(data);
#
#   // A와 B 사이에 NEW를 넣는 핵심 로직
#   newNode.next = nodeB;   // 1. 새 노드의 다음을 B로
#   newNode.prev = nodeA;   // 2. 새 노드의 이전을 A로
#   nodeA.next = newNode;   // 3. A의 다음을 새 노드로
#   nodeB.prev = newNode;   // 4. B의 이전을 새 노드로
#
#   console.log(`[InsertBetween] '${nodeA.data}'와 '${nodeB.data}' 사이에 '${data}' 삽입 완료`);
#   console.log(`결과 구조: ${nodeA.data} <-> ${newNode.data} <-> ${nodeB.data}`);
# }
#
# // 실행 예시 및 출력
# // (nodeA: "데이터1", nodeB: "데이터2"가 있다고 가정)
# insertBetween(nodeA, nodeB, "NEW");
# Out:
# Overwriting doubleNode.js

# %%
# !node doubleNode.js
# Out:
# [Doubly-Prepend] '이중데이터1' 삽입 후 상태: {
#   "head": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   },
#   "size": 1,
#   "tail": {
#     "data": "이중데이터1",
#     "prev": null,
#     "next": null
#   }
# }
# [InsertBetween] 'nodeA'와 'nodeB' 사이에 'NEW' 삽입 완료
# 결과 구조: nodeA <-> NEW <-> nodeB

# %%
# %%writefile doubleNode.js
#
# // [배열의 성능 측정] 데이터 10만 개를 맨 앞에 삽입할 때
#
# const arr = [];
#
# console.time('Array unshift'); // 타이머 시작
#
# for (let i = 0; i < 100000; i++) {
#   arr.unshift(i); // 기존 인덱스 10만 개를 매번 뒤로 밀어냄 (O(n))
# }
#
# console.timeEnd('Array unshift'); // 타이머 종료 및 소요 시간 출력
#
# /* 출력 예시 (시스템 환경에 따라 다름):
# Array unshift: 2542.123ms
# - 설명: 배열은 새로운 요소를 맨 앞에 넣을 때마다 기존의 모든 요소(최대 10만 개)를
#   메모리상에서 한 칸씩 뒤로 이동시켜야 하므로 데이터가 많아질수록 기하급수적으로 느려집니다.
# */
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
# }
#
# // 실행 예시 및 출력
# prepend(list, "데이터1");
# // 출력: { "head": { "data": "데이터1", "next": null }, "size": 1 }
#
# prepend(list, "데이터2");
#
# let myList = { head: null };
#
# console.time('List prepend'); // 타이머 시작
#
# for (let i = 0; i < 100000; i++) {
#   prepend(myList, i); // 참조값 1개(head)만 바꾸고 끝냄 (O(1))
# }
#
# console.timeEnd('List prepend');
# Out:
# Overwriting doubleNode.js

# %%
# !node doubleNode.js
# Out:
# Array unshift: 1.172s
# List prepend: 23.493ms

# %%
# %%writefile dequeue.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
# }
#
# prepend(list, "데이터3");
# prepend(list, "데이터2");
# // [실행 전] 초기 상태: { "head": { "data": "데이터2", "next": { "data": "데이터3", "next": null } }, "size": 2 }
#
# function dequeue(list) {
#   if (!list.head) return null;
#
#   const removedData = list.head.data;
#   list.head = list.head.next; // 1. 맨 앞 노드(Head)를 버리고 다음 노드를 새로운 Head로 지정
#   list.size--;                // 2. 리스트 크기 감소
#
#   console.log(`[dequeue] '${removedData}' 추출 완료. 새로운 Head: ${list.head ? list.head.data : 'null'}`);
#   return removedData;
# }
#
# // 실행 예시 및 출력
# const data = dequeue(list);
# /* 출력:
# [dequeue] '데이터2' 추출 완료. 새로운 Head: 데이터3
# 최종 리스트 상태: { "head": { "data": "데이터3", "next": null }, "size": 1 }
# - 설명: 연결 리스트를 활용한 큐(Queue)에서 dequeue는
#   단순히 head의 참조만 다음으로 옮기면 되므로 O(1)의 성능을 유지합니다.
# */
# Out:
# Overwriting dequeue.js

# %%
# !node dequeue.js
# Out:
# [dequeue] '데이터2' 추출 완료. 새로운 Head: 데이터3

# %%
# %%writefile circular.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
# }
#
# prepend(list, "데이터3");
# // [실행 전] 상황: Head -> [데이터3] -> null
#
# function makeCircular(list) {
#   if (!list.head) return;
#
#   let last = list.head;
#
#   // 1. 마지막 노드(Tail)를 찾을 때까지 이동
#   while (last.next) {
#     last = last.next;
#   }
#
#   // 2. 마지막 노드의 next를 다시 head로 연결 (순환 고리 형성)
#   last.next = list.head;
#
#   console.log(`[Circular] 마지막 노드 '${last.data}'의 next를 Head '${list.head.data}'로 연결 완료`);
#   console.log(`확인: list.head.next... (무한 반복 가능 구조)`);
# }
#
# // 실행 예시 및 출력
# makeCircular(list);
#
# /* 출력:
# [Circular] 마지막 노드 '데이터3'의 next를 Head '데이터3'로 연결 완료
# - 설명: 이제 마지막 노드는 null을 가리키지 않고 다시 처음으로 돌아갑니다.
#   이 구조는 '무한 루프 재생 목록'이나 '라운드 로빈 스케줄링'에 활용됩니다.
# */
# Out:
# Writing circular.js

# %%
# !node circular.js
# Out:
# [Circular] 마지막 노드 '데이터3'의 next를 Head '데이터3'로 연결 완료
# 확인: list.head.next... (무한 반복 가능 구조)

# %%
# %%writefile list.js
#
# // 노드 생성 함수: 데이터와 next 포인터를 가진 객체 반환
# const createNode = (data) => ({
#   data: data,
#   next: null
# });
#
# // 연결 리스트 초기 상태 (Head가 비어있음)
# let myLinkedList = { head: null, size: 0 };
#
# console.log("--- 리스트 초기화 완료 ---");
# console.log(myLinkedList);
#
# // 맨 앞에 삽입 (Prepend): O(1)
# function insertAtFront(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
#   console.log(`[삽입] 맨 앞에 ${data} 추가 완료`);
# }
#
# // 맨 뒤에 삽입 (Append): O(n)
# function insertAtBack(list, data) {
#   const newNode = createNode(data);
#   if (!list.head) {
#     list.head = newNode;
#   } else {
#     let curr = list.head;
#     while (curr.next) { curr = curr.next; } // 끝까지 탐색
#     curr.next = newNode;
#   }
#   list.size++;
#   console.log(`[삽입] 맨 뒤에 ${data} 추가 완료`);
# }
#
# insertAtFront(myLinkedList, "노드1");
# insertAtBack(myLinkedList, "노드2");
# insertAtBack(myLinkedList, "노드3");
#
# function findNode(list, targetData) {
#   let curr = list.head;
#   let index = 0;
#
#   while (curr) {
#     if (curr.data === targetData) {
#       console.log(`[탐색 성공] '${targetData}'를 인덱스 ${index}에서 찾았습니다.`);
#       return curr;
#     }
#     curr = curr.next;
#     index++;
#   }
#   console.log(`[탐색 실패] '${targetData}'가 리스트에 없습니다.`);
#   return null;
# }
#
# findNode(myLinkedList, "노드2");
# findNode(myLinkedList, "노드99"); // 실패 케이스
#
# function deleteNode(list, targetData) {
#   if (!list.head) return;
#
#   // 1. 삭제할 대상이 Head일 때
#   if (list.head.data === targetData) {
#     list.head = list.head.next;
#     list.size--;
#     console.log(`[삭제] Head 노드 '${targetData}' 삭제 완료`);
#     return;
#   }
#
#   // 2. 삭제할 대상의 이전 노드(prev) 찾기
#   let prev = list.head;
#   while (prev.next && prev.next.data !== targetData) {
#     prev = prev.next;
#   }
#
#   // 3. 연결 변경 (건너뛰기)
#   if (prev.next) {
#     prev.next = prev.next.next;
#     list.size--;
#     console.log(`[삭제] 중간 노드 '${targetData}' 삭제 완료`);
#   } else {
#     console.log(`[삭제 실패] '${targetData}'를 찾을 수 없습니다.`);
#   }
# }
#
# deleteNode(myLinkedList, "노드2"); // 중간 삭제
#
# function printList(list) {
#   let curr = list.head;
#   let result = "Head -> ";
#
#   while (curr) {
#     result += `[${curr.data}] -> `;
#     curr = curr.next;
#   }
#
#   result += "null";
#   console.log("--- 현재 리스트 상태 ---");
#   console.log(result);
#   console.log(`총 노드 개수: ${list.size}`);
# }
#
# printList(myLinkedList);
# Out:
# Overwriting list.js

# %%
# !node list.js
# Out:
# --- 리스트 초기화 완료 ---
# { head: null, size: 0 }
# [삽입] 맨 앞에 노드1 추가 완료
# [삽입] 맨 뒤에 노드2 추가 완료
# [삽입] 맨 뒤에 노드3 추가 완료
# [탐색 성공] '노드2'를 인덱스 1에서 찾았습니다.
# [탐색 실패] '노드99'가 리스트에 없습니다.
# [삭제] 중간 노드 '노드2' 삭제 완료
# --- 현재 리스트 상태 ---
# Head -> [노드1] -> [노드3] -> null
# 총 노드 개수: 2

# %%
# %%writefile codingTest1.js
#
# let input = {
#   head: { data: "철수", next: { data: "영희", next: { data: "민수", next: null } } }
# }
#
# let current = input.head;
#
# while (true) {
#   current = current.next;
#
#   if (current.next === null) {
#     console.log(`"${current.data}"`);
#     return;
#   }
# }
# Out:
# Overwriting codingTest1.js

# %%
# !node codingTest1.js
# Out:
# "민수"

# %%
# %%writefile codingTest2.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
# }
#
# // 상황 구현
# prepend(list, "nodeB");
# prepend(list, "nodeA");
#
# // 로직 구현
# function append(list, data) {
#   const newNode = createNode(data);
#
#   newNode.next = list.head.next; // newNode에 뒤의 내용 연결
#   list.head.next = newNode; // head에 newNode 연결
#
#   list.size++;
#   console.log(`[append] '${data}' 삽입 후 리스트 상태:`, JSON.stringify(list, null, 2));
# }
# append(list, "newNode");
# Out:
# Overwriting codingTest2.js

# %%
# !node codingTest2.js
# Out:
# [append] 'newNode' 삽입 후 리스트 상태: {
#   "head": {
#     "data": "nodeA",
#     "next": {
#       "data": "newNode",
#       "next": {
#         "data": "nodeB",
#         "next": null
#       }
#     }
#   },
#   "size": 3
# }

# %%
# %%writefile codingTest3.js
#
# const createNode = (data) => ({
#   data,
#   next: null
# });
#
# let list = {
#   head: null,
#   size: 0
# };
#
# function prepend(list, data) {
#   const newNode = createNode(data);
#   newNode.next = list.head; // 새 노드가 기존 head를 가리킴
#   list.head = newNode;      // head를 새 노드로 교체
#   list.size++;
# }
#
# // 상황 구현
# prepend(list, null);
# prepend(list, 30);
# prepend(list, 20);
# prepend(list, 10);
#
# // 로직 구현
# let sum = 0;
# let curr = list.head;
#
# while (true) {
#   if (curr === null) {
#     console.log(sum);
#     return;
#   }
#
#   sum += curr.data;
#   curr = curr.next;
# }
# Out:
# Overwriting codingTest3.js

# %%
# !node codingTest3.js
# Out:
# 60
