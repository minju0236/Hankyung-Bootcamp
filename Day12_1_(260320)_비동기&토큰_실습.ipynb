# %% [markdown]
# <a href="https://colab.research.google.com/github/minju0236/Hankyung-Bootcamp/blob/main/Day12_1_(260320)_%EB%B9%84%EB%8F%99%EA%B8%B0%26%ED%86%A0%ED%81%B0_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 직원 관리 비동기

# %%
# %%writefile server.js
#
# const express = require('express');
# const path = require('path');
# const fs = require('fs');
# const mysql = require('mysql2/promise');
#
# const app = express();
# const PORT = 3000;
#
# app.use(express.urlencoded({ extended: true }));
# app.use(express.json());
# app.use('/static', express.static(path.join(__dirname, 'static')));
#
# const conn = mysql.createPool({
#     host: 'localhost',
#     user: 'testuser',
#     password: '1234',
#     database: 'testdb',
#     waitForConnections: true,
#     connectionLimit: 10,
#     queueLimit: 0
# });
#
# async function checkDbConnection() {
#     try {
#         const connection = await conn.getConnection();
#         console.log('DB 연결 성공');
#         connection.release();
#     } catch (err) {
#         console.error('DB 연결 실패:', err);
#     }
# }
#
# checkDbConnection();
#
# function escapeHtml(value) {
#     if (value === null || value === undefined) {
#         return '';
#     }
#
#     return String(value)
#         .replace(/&/g, '&amp;')
#         .replace(/</g, '&lt;')
#         .replace(/>/g, '&gt;')
#         .replace(/"/g, '&quot;')
#         .replace(/'/g, '&#39;');
# }
#
# function readTemplate(fileName) {
#     const filePath = path.join(__dirname, 'templates', fileName);
#     return fs.readFileSync(filePath, 'utf8');
# }
#
# function renderTemplate(template, data) {
#     let html = template;
#
#     for (const key in data) {
#         const pattern = new RegExp(`{{${key}}}`, 'g');
#         html = html.replace(pattern, data[key]);
#     }
#
#     return html;
# }
#
# function sendMessagePage(res, title, message) {
#     const template = readTemplate('employee-message.html');
#     const html = renderTemplate(template, {
#         title: escapeHtml(title),
#         message: escapeHtml(message)
#     });
#     res.send(html);
# }
#
# function formatMoney(value) {
#     return Number(value).toLocaleString('ko-KR');
# }
#
# function getStatusSelectedMap(status) {
#     return {
#         selected_status_working: status === '재직' ? 'selected' : '',
#         selected_status_promoted: status === '승진' ? 'selected' : '',
#         selected_status_leave: status === '휴직' ? 'selected' : '',
#         selected_status_resigned: status === '퇴사' ? 'selected' : ''
#     };
# }
#
# function isAjaxRequest(req) {
#     const requestedWith = req.get('X-Requested-With');
#     const accept = req.get('Accept') || '';
#     return requestedWith === 'XMLHttpRequest' || accept.includes('application/json');
# }
#
# function sendAjaxSuccess(res, message, redirectUrl) {
#     return res.json({
#         success: true,
#         message,
#         redirectUrl
#     });
# }
#
# function sendAjaxFail(res, message, statusCode = 500) {
#     return res.status(statusCode).json({
#         success: false,
#         message
#     });
# }
#
# app.get('/', async (req, res) => {
#     res.redirect('/employee/list');
# });
#
# app.get('/employee/list', async (req, res) => {
#     try {
#         const sql = `
#             SELECT
#                 employee_id,
#                 emp_no,
#                 name,
#                 department,
#                 position,
#                 employment_status,
#                 annual_salary,
#                 DATE_FORMAT(hire_date, '%Y-%m-%d') AS hire_date
#             FROM employee
#             ORDER BY employee_id DESC
#         `;
#
#         const [rows] = await conn.query(sql);
#
#         let tableSection = '';
#
#         if (rows.length === 0) {
#             tableSection = `<div class="empty-box">등록된 직원 정보가 없습니다.</div>`;
#         } else {
#             let rowsHtml = '';
#
#             for (let i = 0; i < rows.length; i++) {
#                 rowsHtml += `
#                     <tr>
#                         <td>${rows[i].employee_id}</td>
#                         <td>${escapeHtml(rows[i].emp_no)}</td>
#                         <td class="title-cell">
#                             <a class="title-link" href="/employee/detail/${rows[i].employee_id}">${escapeHtml(rows[i].name)}</a>
#                         </td>
#                         <td>${escapeHtml(rows[i].department)}</td>
#                         <td>${escapeHtml(rows[i].position)}</td>
#                         <td>${escapeHtml(rows[i].employment_status)}</td>
#                         <td class="money">${formatMoney(rows[i].annual_salary)}원</td>
#                         <td>${rows[i].hire_date}</td>
#                         <td>
#                             <a class="action-link view-link" href="/employee/detail/${rows[i].employee_id}">조회</a>
#                         </td>
#                         <td>
#                             <a class="action-link edit-link" href="/employee/edit/${rows[i].employee_id}">수정</a>
#                         </td>
#                         <td>
#                             <form class="inline-form delete-form" action="/employee/delete/${rows[i].employee_id}" method="post" onsubmit="return false;">
#                                 <button class="delete-btn" type="submit">삭제</button>
#                             </form>
#                         </td>
#                     </tr>
#                 `;
#             }
#
#             tableSection = `
#                 <div class="table-wrap">
#                     <table>
#                         <thead>
#                             <tr>
#                                 <th class="col-id">번호</th>
#                                 <th class="col-empno">사번</th>
#                                 <th class="col-name">직원명</th>
#                                 <th class="col-dept">부서</th>
#                                 <th class="col-position">직급</th>
#                                 <th class="col-status">상태</th>
#                                 <th class="col-salary">연봉</th>
#                                 <th class="col-date">입사일</th>
#                                 <th class="col-action">조회</th>
#                                 <th class="col-action">수정</th>
#                                 <th class="col-action">삭제</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             ${rowsHtml}
#                         </tbody>
#                     </table>
#                 </div>
#             `;
#         }
#
#         const template = readTemplate('employee-list.html');
#         const html = renderTemplate(template, {
#             table_section: tableSection
#         });
#
#         res.send(html);
#     } catch (err) {
#         console.error('직원 목록 조회 실패:', err);
#         return sendMessagePage(res, '조회 실패', '직원 목록 조회 중 오류가 발생했습니다.');
#     }
# });
#
# app.get('/employee/write', async (req, res) => {
#     res.sendFile(path.join(__dirname, 'templates', 'employee-write.html'));
# });
#
# app.post('/employee/write', async (req, res) => {
#     try {
#         const {
#             emp_no,
#             name,
#             department,
#             position,
#             hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note
#         } = req.body;
#
#         const sql = `
#             INSERT INTO employee (
#                 emp_no,
#                 name,
#                 department,
#                 position,
#                 hire_date,
#                 employment_status,
#                 annual_salary,
#                 tax,
#                 bonus,
#                 address,
#                 phone,
#                 email,
#                 hr_note,
#                 created_at
#             )
#             VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, CONVERT_TZ(UTC_TIMESTAMP(), '+00:00', '+09:00'))
#         `;
#
#         await conn.query(sql, [
#             emp_no,
#             name,
#             department,
#             position,
#             hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note
#         ]);
#
#         if (isAjaxRequest(req)) {
#             return sendAjaxSuccess(res, '직원 정보가 저장되었습니다.', '/employee/list');
#         }
#
#         res.redirect('/employee/list');
#     } catch (err) {
#         console.error('직원 정보 저장 실패:', err);
#
#         if (isAjaxRequest(req)) {
#             return sendAjaxFail(res, '직원 정보 저장 중 오류가 발생했습니다.');
#         }
#
#         return sendMessagePage(res, '저장 실패', '직원 정보 저장 중 오류가 발생했습니다.');
#     }
# });
#
# app.get('/employee/detail/:id', async (req, res) => {
#     try {
#         const employeeId = req.params.id;
#
#         const sql = `
#             SELECT
#                 employee_id,
#                 emp_no,
#                 name,
#                 department,
#                 position,
#                 DATE_FORMAT(hire_date, '%Y-%m-%d') AS hire_date,
#                 employment_status,
#                 annual_salary,
#                 tax,
#                 bonus,
#                 address,
#                 phone,
#                 email,
#                 hr_note,
#                 DATE_FORMAT(created_at, '%Y-%m-%d %H:%i:%s') AS created_at
#             FROM employee
#             WHERE employee_id = ?
#         `;
#
#         const [rows] = await conn.query(sql, [employeeId]);
#
#         if (rows.length === 0) {
#             return sendMessagePage(res, '조회 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         const row = rows[0];
#         const template = readTemplate('employee-detail.html');
#         const html = renderTemplate(template, {
#             employee_id: String(row.employee_id),
#             emp_no: escapeHtml(row.emp_no),
#             name: escapeHtml(row.name),
#             department: escapeHtml(row.department),
#             position: escapeHtml(row.position),
#             hire_date: row.hire_date,
#             employment_status: escapeHtml(row.employment_status),
#             annual_salary: formatMoney(row.annual_salary),
#             tax: formatMoney(row.tax),
#             bonus: formatMoney(row.bonus),
#             address: escapeHtml(row.address),
#             phone: escapeHtml(row.phone),
#             email: escapeHtml(row.email),
#             hr_note: escapeHtml(row.hr_note),
#             created_at: row.created_at
#         });
#
#         res.send(html);
#     } catch (err) {
#         console.error('직원 상세 조회 실패:', err);
#         return sendMessagePage(res, '조회 실패', '직원 정보 조회 중 오류가 발생했습니다.');
#     }
# });
#
# app.get('/employee/edit/:id', async (req, res) => {
#     try {
#         const employeeId = req.params.id;
#
#         const sql = `
#             SELECT
#                 employee_id,
#                 emp_no,
#                 name,
#                 department,
#                 position,
#                 DATE_FORMAT(hire_date, '%Y-%m-%d') AS hire_date,
#                 employment_status,
#                 annual_salary,
#                 tax,
#                 bonus,
#                 address,
#                 phone,
#                 email,
#                 hr_note
#             FROM employee
#             WHERE employee_id = ?
#         `;
#
#         const [rows] = await conn.query(sql, [employeeId]);
#
#         if (rows.length === 0) {
#             return sendMessagePage(res, '조회 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         const row = rows[0];
#         const statusSelectedMap = getStatusSelectedMap(row.employment_status);
#
#         const template = readTemplate('employee-edit.html');
#         const html = renderTemplate(template, {
#             employee_id: String(row.employee_id),
#             emp_no: escapeHtml(row.emp_no),
#             name: escapeHtml(row.name),
#             department: escapeHtml(row.department),
#             position: escapeHtml(row.position),
#             hire_date: row.hire_date,
#             annual_salary: String(row.annual_salary),
#             tax: String(row.tax),
#             bonus: String(row.bonus),
#             address: escapeHtml(row.address),
#             phone: escapeHtml(row.phone),
#             email: escapeHtml(row.email),
#             hr_note: escapeHtml(row.hr_note),
#             selected_status_working: statusSelectedMap.selected_status_working,
#             selected_status_promoted: statusSelectedMap.selected_status_promoted,
#             selected_status_leave: statusSelectedMap.selected_status_leave,
#             selected_status_resigned: statusSelectedMap.selected_status_resigned
#         });
#
#         res.send(html);
#     } catch (err) {
#         console.error('수정 화면 조회 실패:', err);
#         return sendMessagePage(res, '조회 실패', '수정 화면 조회 중 오류가 발생했습니다.');
#     }
# });
#
# app.post('/employee/edit/:id', async (req, res) => {
#     try {
#         const employeeId = req.params.id;
#         const {
#             emp_no,
#             name,
#             department,
#             position,
#             hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note
#         } = req.body;
#
#         const sql = `
#             UPDATE employee
#             SET
#                 emp_no = ?,
#                 name = ?,
#                 department = ?,
#                 position = ?,
#                 hire_date = ?,
#                 employment_status = ?,
#                 annual_salary = ?,
#                 tax = ?,
#                 bonus = ?,
#                 address = ?,
#                 phone = ?,
#                 email = ?,
#                 hr_note = ?
#             WHERE employee_id = ?
#         `;
#
#         const [result] = await conn.query(sql, [
#             emp_no,
#             name,
#             department,
#             position,
#             hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note,
#             employeeId
#         ]);
#
#         if (result.affectedRows === 0) {
#             if (isAjaxRequest(req)) {
#                 return sendAjaxFail(res, '해당 직원 정보가 존재하지 않습니다.', 404);
#             }
#
#             return sendMessagePage(res, '수정 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         if (isAjaxRequest(req)) {
#             return sendAjaxSuccess(res, '직원 정보가 수정되었습니다.', `/employee/detail/${employeeId}`);
#         }
#
#         res.redirect('/employee/detail/' + employeeId);
#     } catch (err) {
#         console.error('직원 정보 수정 실패:', err);
#
#         if (isAjaxRequest(req)) {
#             return sendAjaxFail(res, '직원 정보 수정 중 오류가 발생했습니다.');
#         }
#
#         return sendMessagePage(res, '수정 실패', '직원 정보 수정 중 오류가 발생했습니다.');
#     }
# });
#
# app.post('/employee/delete/:id', async (req, res) => {
#     try {
#         const employeeId = req.params.id;
#
#         const sql = `
#             DELETE FROM employee
#             WHERE employee_id = ?
#         `;
#
#         const [result] = await conn.query(sql, [employeeId]);
#
#         if (result.affectedRows === 0) {
#             if (isAjaxRequest(req)) {
#                 return sendAjaxFail(res, '해당 직원 정보가 존재하지 않습니다.', 404);
#             }
#
#             return sendMessagePage(res, '삭제 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         if (isAjaxRequest(req)) {
#             return sendAjaxSuccess(res, '직원 정보가 삭제되었습니다.', '/employee/list');
#         }
#
#         res.redirect('/employee/list');
#     } catch (err) {
#         console.error('직원 정보 삭제 실패:', err);
#
#         if (isAjaxRequest(req)) {
#             return sendAjaxFail(res, '직원 정보 삭제 중 오류가 발생했습니다.');
#         }
#
#         return sendMessagePage(res, '삭제 실패', '직원 정보 삭제 중 오류가 발생했습니다.');
#     }
# });
#
# app.listen(PORT, () => {
#     console.log('=========================================');
#     console.log(` 인사관리 서버가 포트 ${PORT}에서 작동 중입니다.`);
#     console.log('=========================================');
# });
# Out:
# Overwriting server.js

# %%
# %%writefile static/style.css
#
# @import url("https://cdn.jsdelivr.net/gh/orioncactus/pretendard@v1.3.9/dist/web/static/pretendard.css");
#
# * {
#     box-sizing: border-box;
# }
#
# html,
# body {
#     margin: 0;
#     padding: 0;
# }
#
# body {
#     background: #f6f8fb;
#     color: #191f28;
#     font-family: "Pretendard", "Noto Sans KR", Arial, sans-serif;
#     line-height: 1.5;
# }
#
# a {
#     color: inherit;
#     text-decoration: none;
# }
#
# button,
# input,
# select,
# textarea {
#     font: inherit;
# }
#
# img {
#     display: block;
# }
#
# .page {
#     max-width: 1280px;
#     margin: 0 auto;
#     padding: 32px 24px 72px;
# }
#
# .page-narrow {
#     max-width: 980px;
# }
#
# .page-mini {
#     max-width: 560px;
# }
#
# .topbar {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     margin-bottom: 28px;
# }
#
# .brand {
#     display: flex;
#     align-items: center;
#     gap: 14px;
# }
#
# .brand-logo {
#     width: 130px;
#     height: auto;
# }
#
# .brand-text {
#     display: flex;
#     flex-direction: column;
#     gap: 2px;
# }
#
# .brand-title {
#     font-size: 14px;
#     font-weight: 700;
#     color: #4e5968;
# }
#
# .brand-subtitle {
#     font-size: 12px;
#     color: #8b95a1;
# }
#
# .topbar-right {
#     display: flex;
#     align-items: center;
#     gap: 10px;
# }
#
# .top-chip {
#     min-height: 38px;
#     padding: 0 14px;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 999px;
#     background: #ffffff;
#     color: #4e5968;
#     border: 1px solid #eef2f6;
#     font-size: 13px;
#     font-weight: 600;
# }
#
# .hero {
#     margin-bottom: 20px;
# }
#
# .hero-title {
#     margin: 0 0 8px;
#     font-size: 36px;
#     line-height: 1.28;
#     letter-spacing: -0.8px;
#     font-weight: 700;
# }
#
# .hero-text {
#     margin: 0;
#     font-size: 15px;
#     color: #8b95a1;
# }
#
# .panel {
#     background: #ffffff;
#     border-radius: 32px;
#     box-shadow: 0 8px 24px rgba(15, 23, 42, 0.05);
#     overflow: hidden;
#     border: 1px solid #eef2f6;
# }
#
# .panel-head {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     padding: 28px 28px 18px;
# }
#
# .panel-title {
#     margin: 0;
#     font-size: 22px;
#     font-weight: 700;
#     letter-spacing: -0.4px;
# }
#
# .panel-text {
#     margin: 4px 0 0;
#     font-size: 14px;
#     color: #8b95a1;
# }
#
# .panel-body {
#     padding: 0 28px 28px;
# }
#
# .btn,
# .btn-secondary,
# .btn-danger,
# .action-link {
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#     min-height: 50px;
#     padding: 0 18px;
#     border-radius: 16px;
#     border: none;
#     cursor: pointer;
#     font-size: 14px;
#     font-weight: 700;
#     white-space: nowrap;
# }
#
# .btn {
#     background: #3182f6;
#     color: #ffffff;
# }
#
# .btn:hover {
#     background: #1b64da;
# }
#
# .btn-secondary {
#     background: #f2f4f6;
#     color: #4e5968;
# }
#
# .btn-secondary:hover {
#     background: #e9ecef;
# }
#
# .btn-danger {
#     background: #f04452;
#     color: #ffffff;
# }
#
# .btn-danger:hover {
#     background: #d92d20;
# }
#
# .flex-1 {
#     flex: 1;
# }
#
# .table-wrap {
#     width: 100%;
#     overflow-x: auto;
# }
#
# table {
#     width: 100%;
#     border-collapse: collapse;
#     table-layout: fixed;
# }
#
# thead th {
#     padding: 16px 10px;
#     background: #fafbfc;
#     border-bottom: 1px solid #eef2f6;
#     font-size: 13px;
#     font-weight: 700;
#     color: #6b7684;
#     text-align: center;
# }
#
# tbody td {
#     padding: 16px 10px;
#     border-bottom: 1px solid #f2f4f6;
#     font-size: 14px;
#     color: #333d4b;
#     text-align: center;
#     vertical-align: middle;
# }
#
# tbody tr:last-child td {
#     border-bottom: none;
# }
#
# .title-cell {
#     text-align: left;
# }
#
# .title-link {
#     font-weight: 700;
#     color: #191f28;
# }
#
# .title-link:hover {
#     color: #3182f6;
# }
#
# .col-id { width: 70px; }
# .col-empno { width: 120px; }
# .col-name { width: 110px; }
# .col-dept { width: 140px; }
# .col-position { width: 90px; }
# .col-status { width: 90px; }
# .col-salary { width: 130px; }
# .col-date { width: 120px; }
# .col-action { width: 84px; }
#
# .action-link {
#     min-height: 36px;
#     padding: 0 12px;
#     border-radius: 12px;
#     font-size: 13px;
# }
#
# .view-link {
#     background: #edf4ff;
#     color: #3182f6;
# }
#
# .edit-link {
#     background: #f2f4f6;
#     color: #4e5968;
# }
#
# .delete-btn {
#     width: 100%;
#     min-height: 36px;
#     padding: 0 12px;
#     border: none;
#     border-radius: 12px;
#     background: #ffe9eb;
#     color: #e11d48;
#     font-size: 13px;
#     font-weight: 700;
#     cursor: pointer;
# }
#
# .inline-form {
#     margin: 0;
#     width: 100%;
# }
#
# .money {
#     white-space: nowrap;
#     font-variant-numeric: tabular-nums;
# }
#
# .empty-box {
#     padding: 64px 20px;
#     text-align: center;
#     color: #8b95a1;
#     font-size: 15px;
#     background: #fbfcfd;
#     border-radius: 22px;
# }
#
# .form-wrap {
#     padding: 28px;
# }
#
# .form-grid {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 20px 18px;
# }
#
# .form-group {
#     min-width: 0;
# }
#
# .form-group.full {
#     grid-column: 1 / -1;
# }
#
# label {
#     display: block;
#     margin-bottom: 10px;
#     font-size: 14px;
#     font-weight: 700;
#     color: #4e5968;
# }
#
# input,
# select,
# textarea {
#     width: 100%;
#     border: 1px solid #e5e8eb;
#     border-radius: 18px;
#     background: #ffffff;
#     color: #191f28;
#     padding: 16px 18px;
#     outline: none;
# }
#
# input:focus,
# select:focus,
# textarea:focus {
#     border-color: #3182f6;
#     box-shadow: 0 0 0 4px rgba(49, 130, 246, 0.12);
# }
#
# textarea {
#     min-height: 180px;
#     line-height: 1.7;
#     resize: vertical;
# }
#
# .button-row {
#     display: flex;
#     gap: 12px;
#     margin-top: 28px;
# }
#
# .summary-strip {
#     display: grid;
#     grid-template-columns: repeat(3, minmax(0, 1fr));
#     gap: 14px;
#     padding: 28px 28px 0;
# }
#
# .summary-card {
#     background: #f9fafb;
#     border-radius: 22px;
#     padding: 18px 20px;
# }
#
# .summary-label {
#     display: block;
#     margin-bottom: 6px;
#     font-size: 13px;
#     font-weight: 700;
#     color: #8b95a1;
# }
#
# .summary-value {
#     font-size: 18px;
#     font-weight: 700;
#     color: #191f28;
#     word-break: break-word;
# }
#
# .detail-wrap {
#     padding: 28px;
# }
#
# .detail-grid {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 16px;
# }
#
# .detail-item {
#     padding: 18px 20px;
#     border: 1px solid #f2f4f6;
#     border-radius: 20px;
#     background: #ffffff;
# }
#
# .detail-item.full {
#     grid-column: 1 / -1;
# }
#
# .detail-label {
#     display: block;
#     margin-bottom: 6px;
#     font-size: 13px;
#     font-weight: 700;
#     color: #8b95a1;
# }
#
# .detail-value {
#     font-size: 15px;
#     color: #191f28;
#     line-height: 1.7;
#     word-break: break-word;
# }
#
# .note-box {
#     margin-top: 16px;
#     padding: 22px;
#     border: 1px solid #f2f4f6;
#     border-radius: 20px;
#     background: #ffffff;
# }
#
# .note-title {
#     margin: 0 0 12px;
#     font-size: 16px;
#     font-weight: 700;
#     color: #191f28;
# }
#
# .note-content {
#     font-size: 15px;
#     color: #333d4b;
#     line-height: 1.8;
#     white-space: pre-wrap;
#     word-break: break-word;
# }
#
# .message-wrap {
#     padding: 40px 28px;
#     text-align: center;
# }
#
# .message-title {
#     margin: 0 0 12px;
#     font-size: 30px;
#     font-weight: 700;
# }
#
# .message-text {
#     margin: 0 0 28px;
#     font-size: 16px;
#     color: #4e5968;
#     line-height: 1.7;
# }
#
# .toast {
#     position: fixed;
#     top: 24px;
#     right: 24px;
#     min-width: 280px;
#     max-width: 420px;
#     padding: 16px 18px;
#     border-radius: 18px;
#     background: #191f28;
#     color: #ffffff;
#     font-size: 14px;
#     font-weight: 600;
#     box-shadow: 0 12px 32px rgba(15, 23, 42, 0.18);
#     z-index: 9999;
#     opacity: 0;
#     transform: translateY(-8px);
#     pointer-events: none;
#     transition: opacity 0.25s ease, transform 0.25s ease;
# }
#
# .toast.show {
#     opacity: 1;
#     transform: translateY(0);
# }
#
# .toast.error {
#     background: #d92d20;
# }
#
# @media (max-width: 980px) {
#     .form-grid,
#     .summary-strip,
#     .detail-grid {
#         grid-template-columns: 1fr;
#     }
# }
#
# @media (max-width: 720px) {
#     .page,
#     .page-narrow,
#     .page-mini {
#         padding: 20px 14px 40px;
#     }
#
#     .topbar {
#         flex-direction: column;
#         align-items: flex-start;
#         gap: 12px;
#     }
#
#     .hero-title {
#         font-size: 28px;
#     }
#
#     .panel-head,
#     .panel-body,
#     .form-wrap,
#     .detail-wrap,
#     .summary-strip,
#     .message-wrap {
#         padding-left: 18px;
#         padding-right: 18px;
#     }
#
#     .button-row {
#         flex-direction: column;
#     }
#
#     .table-wrap table {
#         min-width: 1120px;
#     }
#
#     .toast {
#         left: 14px;
#         right: 14px;
#         top: 14px;
#         min-width: auto;
#         max-width: none;
#     }
# }
# Out:
# Writing static/style.css
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4104/1193474007.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('writefile', 'static/style.css', '\n@import url("https://cdn.jsdelivr.net/gh/orioncactus/pretendard@v1.3.9/dist/web/static/pretendard.css");\n\n* {\n    box-sizing: border-box;\n}\n\nhtml,\nbody {\n    margin: 0;\n    padding: 0;\n}\n\nbody {\n    background: #f6f8fb;\n    color: #191f28;\n    font-family: "Pretendard", "Noto Sans KR", Arial, sans-serif;\n    line-height: 1.5;\n}\n\na {\n    color: inherit;\n    text-decoration: none;\n}\n\nbutton,\ninput,\nselect,\ntextarea {\n    font: inherit;\n}\n\nimg {\n    display: block;\n}\n\n.page {\n    max-width: 1280px;\n    margin: 0 auto;\n    padding: 32px 24px 72px;\n}\n\n.page-narrow {\n    max-width: 980px;\n}\n\n.page-mini {\n    max-width: 560px;\n}\n\n.topbar {\n    display: flex;\n    align-items: center;\n    justify-content: space-between;\n    margin-bottom: 28px;\n}\n\n.brand {\n    display: flex;\n    align-items: center;\n    gap: 14px;\n}\n\n.brand-logo {\n    width: 130px;\n    height: auto;\n}\n\n.brand-text {\n    display: flex;\n    flex-direction: column;\n    gap: 2px;\n}\n\n.brand-title {\n    font-size: 14px;\n    font-weight: 700;\n    color: #4e5968;\n}\n\n.brand-subtitle {\n    font-size: 12px;\n    color: #8b95a1;\n}\n\n.topbar-right {\n    display: flex;\n    align-items: center;\n    gap: 10px;\n}\n\n.top-chip {\n    min-height: 38px;\n ...
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     221     if line and not cell:
#     222       cell = ' '
# --> 223     return super().run_cell_magic(magic_name, line, cell)
#     224
#     225
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-98> in writefile(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/osm.py in writefile(self, line, cell)
#     854
#     855         mode = 'a' if args.append else 'w'
# --> 856         with io.open(filename, mode, encoding='utf-8') as f:
#     857             f.write(cell)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'static/style.css'

# %%
# %%writefile templates/employee-list.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 목록</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <span class="top-chip">HR Admin</span>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 목록</h1>
#             <p class="hero-text">직원 정보를 조회하고 관리합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="panel-head">
#                 <div>
#                     <h2 class="panel-title">전체 직원</h2>
#                     <p class="panel-text">등록된 직원 데이터를 확인할 수 있습니다.</p>
#                 </div>
#                 <a class="btn" href="/employee/write">직원 등록</a>
#             </div>
#
#             <div class="panel-body">
#                 {{table_section}}
#             </div>
#         </div>
#     </div>
#
#     <div id="toast" class="toast"></div>
#
#     <script>
#         function showToast(message, isError = false) {
#             const toast = document.getElementById('toast');
#             toast.textContent = message;
#             toast.className = isError ? 'toast show error' : 'toast show';
#
#             setTimeout(() => {
#                 toast.className = isError ? 'toast error' : 'toast';
#             }, 2200);
#         }
#
#         async function deleteEmployee(formElement) {
#             try {
#                 const response = await fetch(formElement.action, {
#                     method: 'POST',
#                     headers: {
#                         'Accept': 'application/json',
#                         'X-Requested-With': 'XMLHttpRequest'
#                     }
#                 });
#
#                 const result = await response.json();
#
#                 if (!response.ok || !result.success) {
#                     throw new Error(result.message || '삭제 처리 중 오류가 발생했습니다.');
#                 }
#
#                 showToast(result.message);
#                 setTimeout(() => {
#                     window.location.href = result.redirectUrl;
#                 }, 500);
#             } catch (error) {
#                 showToast(error.message, true);
#             }
#         }
#
#         document.addEventListener('DOMContentLoaded', () => {
#             const deleteForms = document.querySelectorAll('.delete-form');
#
#             deleteForms.forEach((formElement) => {
#                 formElement.addEventListener('submit', async (event) => {
#                     event.preventDefault();
#
#                     const isConfirmed = confirm('정말 삭제하시겠습니까?');
#
#                     if (!isConfirmed) {
#                         return;
#                     }
#
#                     await deleteEmployee(formElement);
#                 });
#             });
#         });
#     </script>
# </body>
# </html>

# %%
# %%writefile templates/employee-write.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 등록</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/employee/list">목록</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 등록</h1>
#             <p class="hero-text">신규 직원 정보를 등록합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="form-wrap">
#                 <form id="employeeWriteForm" action="/employee/write" method="post">
#                     <div class="form-grid">
#                         <div class="form-group">
#                             <label for="emp_no">사번</label>
#                             <input type="text" id="emp_no" name="emp_no" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="name">직원명</label>
#                             <input type="text" id="name" name="name" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="department">부서</label>
#                             <input type="text" id="department" name="department" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="position">직급</label>
#                             <input type="text" id="position" name="position" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="hire_date">입사일</label>
#                             <input type="date" id="hire_date" name="hire_date" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="employment_status">재직상태</label>
#                             <select id="employment_status" name="employment_status" required>
#                                 <option value="재직">재직</option>
#                                 <option value="승진">승진</option>
#                                 <option value="휴직">휴직</option>
#                                 <option value="퇴사">퇴사</option>
#                             </select>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="annual_salary">연봉</label>
#                             <input type="number" id="annual_salary" name="annual_salary" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="tax">세금</label>
#                             <input type="number" id="tax" name="tax" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="bonus">보너스</label>
#                             <input type="number" id="bonus" name="bonus" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="phone">연락처</label>
#                             <input type="text" id="phone" name="phone" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="address">주소</label>
#                             <input type="text" id="address" name="address" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="email">이메일</label>
#                             <input type="email" id="email" name="email" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="hr_note">인사 메모</label>
#                             <textarea id="hr_note" name="hr_note" required></textarea>
#                         </div>
#                     </div>
#
#                     <div class="button-row">
#                         <button class="btn flex-1" type="submit">저장하기</button>
#                         <a class="btn-secondary flex-1" href="/employee/list">취소</a>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
#
#     <div id="toast" class="toast"></div>
#
#     <script>
#         function showToast(message, isError = false) {
#             const toast = document.getElementById('toast');
#             toast.textContent = message;
#             toast.className = isError ? 'toast show error' : 'toast show';
#
#             setTimeout(() => {
#                 toast.className = isError ? 'toast error' : 'toast';
#             }, 2200);
#         }
#
#         async function submitEmployeeWriteForm(formElement) {
#             try {
#                 const formData = new FormData(formElement);
#                 const payload = Object.fromEntries(formData.entries());
#
#                 const response = await fetch(formElement.action, {
#                     method: 'POST',
#                     headers: {
#                         'Content-Type': 'application/json',
#                         'Accept': 'application/json',
#                         'X-Requested-With': 'XMLHttpRequest'
#                     },
#                     body: JSON.stringify(payload)
#                 });
#
#                 const result = await response.json();
#
#                 if (!response.ok || !result.success) {
#                     throw new Error(result.message || '저장 처리 중 오류가 발생했습니다.');
#                 }
#
#                 showToast(result.message);
#                 setTimeout(() => {
#                     window.location.href = result.redirectUrl;
#                 }, 500);
#             } catch (error) {
#                 showToast(error.message, true);
#             }
#         }
#
#         document.getElementById('employeeWriteForm').addEventListener('submit', async (event) => {
#             event.preventDefault();
#             await submitEmployeeWriteForm(event.currentTarget);
#         });
#     </script>
# </body>
# </html>
#
#     <div id="toast" class="toast"></div>
#
#     <script>
#         function showToast(message, isError = false) {
#             const toast = document.getElementById('toast');
#             toast.textContent = message;
#             toast.className = isError ? 'toast show error' : 'toast show';
#
#             setTimeout(() => {
#                 toast.className = isError ? 'toast error' : 'toast';
#             }, 2200);
#         }
#
#         async function deleteEmployee(formElement) {
#             try {
#                 const response = await fetch(formElement.action, {
#                     method: 'POST',
#                     headers: {
#                         'Accept': 'application/json',
#                         'X-Requested-With': 'XMLHttpRequest'
#                     }
#                 });
#
#                 const result = await response.json();
#
#                 if (!response.ok || !result.success) {
#                     throw new Error(result.message || '삭제 처리 중 오류가 발생했습니다.');
#                 }
#
#                 showToast(result.message);
#                 setTimeout(() => {
#                     window.location.href = result.redirectUrl;
#                 }, 500);
#             } catch (error) {
#                 showToast(error.message, true);
#             }
#         }
#
#         document.addEventListener('DOMContentLoaded', () => {
#             const deleteForms = document.querySelectorAll('.delete-form');
#
#             deleteForms.forEach((formElement) => {
#                 formElement.addEventListener('submit', async (event) => {
#                     event.preventDefault();
#
#                     const isConfirmed = confirm('정말 삭제하시겠습니까?');
#
#                     if (!isConfirmed) {
#                         return;
#                     }
#
#                     await deleteEmployee(formElement);
#                 });
#             });
#         });
#     </script>
# </body>
# </html>

# %%
# %%writefile templates/employee-detail.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 상세</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/employee/list">목록</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 상세</h1>
#             <p class="hero-text">직원 인사 정보를 확인합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="summary-strip">
#                 <div class="summary-card">
#                     <span class="summary-label">직원번호</span>
#                     <div class="summary-value">{{employee_id}}</div>
#                 </div>
#                 <div class="summary-card">
#                     <span class="summary-label">직원명</span>
#                     <div class="summary-value">{{name}}</div>
#                 </div>
#                 <div class="summary-card">
#                     <span class="summary-label">등록일시</span>
#                     <div class="summary-value">{{created_at}}</div>
#                 </div>
#             </div>
#
#             <div class="detail-wrap">
#                 <div class="detail-grid">
#                     <div class="detail-item">
#                         <span class="detail-label">사번</span>
#                         <div class="detail-value">{{emp_no}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">부서</span>
#                         <div class="detail-value">{{department}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">직급</span>
#                         <div class="detail-value">{{position}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">입사일</span>
#                         <div class="detail-value">{{hire_date}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">재직상태</span>
#                         <div class="detail-value">{{employment_status}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">연봉</span>
#                         <div class="detail-value money">{{annual_salary}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">세금</span>
#                         <div class="detail-value money">{{tax}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">보너스</span>
#                         <div class="detail-value money">{{bonus}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">연락처</span>
#                         <div class="detail-value">{{phone}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">이메일</span>
#                         <div class="detail-value">{{email}}</div>
#                     </div>
#
#                     <div class="detail-item full">
#                         <span class="detail-label">주소</span>
#                         <div class="detail-value">{{address}}</div>
#                     </div>
#                 </div>
#
#                 <div class="note-box">
#                     <h2 class="note-title">인사 메모</h2>
#                     <div class="note-content">{{hr_note}}</div>
#                 </div>
#
#                 <div class="button-row">
#                     <a class="btn-secondary flex-1" href="/employee/list">목록</a>
#                     <a class="btn flex-1" href="/employee/edit/{{employee_id}}">수정</a>
#                     <form id="employeeDeleteForm" class="inline-form flex-1" action="/employee/delete/{{employee_id}}" method="post" onsubmit="return false;">
#                         <button class="btn-danger" type="submit" style="width: 100%;">삭제</button>
#                     </form>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div id="toast" class="toast"></div>
#
#     <script>
#         function showToast(message, isError = false) {
#             const toast = document.getElementById('toast');
#             toast.textContent = message;
#             toast.className = isError ? 'toast show error' : 'toast show';
#
#             setTimeout(() => {
#                 toast.className = isError ? 'toast error' : 'toast';
#             }, 2200);
#         }
#
#         async function deleteEmployee(formElement) {
#             try {
#                 const response = await fetch(formElement.action, {
#                     method: 'POST',
#                     headers: {
#                         'Accept': 'application/json',
#                         'X-Requested-With': 'XMLHttpRequest'
#                     }
#                 });
#
#                 const result = await response.json();
#
#                 if (!response.ok || !result.success) {
#                     throw new Error(result.message || '삭제 처리 중 오류가 발생했습니다.');
#                 }
#
#                 showToast(result.message);
#                 setTimeout(() => {
#                     window.location.href = result.redirectUrl;
#                 }, 500);
#             } catch (error) {
#                 showToast(error.message, true);
#             }
#         }
#
#         document.getElementById('employeeDeleteForm').addEventListener('submit', async (event) => {
#             event.preventDefault();
#
#             const isConfirmed = confirm('정말 삭제하시겠습니까?');
#
#             if (!isConfirmed) {
#                 return;
#             }
#
#             await deleteEmployee(event.currentTarget);
#         });
#     </script>
# </body>
# </html>

# %%
# %%writefile templates/employee-edit.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 수정</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/employee/detail/{{employee_id}}">상세</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 수정</h1>
#             <p class="hero-text">직원 인사 정보를 수정합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="form-wrap">
#                 <form id="employeeEditForm" action="/employee/edit/{{employee_id}}" method="post">
#                     <div class="form-grid">
#                         <div class="form-group">
#                             <label for="emp_no">사번</label>
#                             <input type="text" id="emp_no" name="emp_no" value="{{emp_no}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="name">직원명</label>
#                             <input type="text" id="name" name="name" value="{{name}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="department">부서</label>
#                             <input type="text" id="department" name="department" value="{{department}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="position">직급</label>
#                             <input type="text" id="position" name="position" value="{{position}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="hire_date">입사일</label>
#                             <input type="date" id="hire_date" name="hire_date" value="{{hire_date}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="employment_status">재직상태</label>
#                             <select id="employment_status" name="employment_status" required>
#                                 <option value="재직" {{selected_status_working}}>재직</option>
#                                 <option value="승진" {{selected_status_promoted}}>승진</option>
#                                 <option value="휴직" {{selected_status_leave}}>휴직</option>
#                                 <option value="퇴사" {{selected_status_resigned}}>퇴사</option>
#                             </select>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="annual_salary">연봉</label>
#                             <input type="number" id="annual_salary" name="annual_salary" value="{{annual_salary}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="tax">세금</label>
#                             <input type="number" id="tax" name="tax" value="{{tax}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="bonus">보너스</label>
#                             <input type="number" id="bonus" name="bonus" value="{{bonus}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="phone">연락처</label>
#                             <input type="text" id="phone" name="phone" value="{{phone}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="address">주소</label>
#                             <input type="text" id="address" name="address" value="{{address}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="email">이메일</label>
#                             <input type="email" id="email" name="email" value="{{email}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="hr_note">인사 메모</label>
#                             <textarea id="hr_note" name="hr_note" required>{{hr_note}}</textarea>
#                         </div>
#                     </div>
#
#                     <div class="button-row">
#                         <button class="btn flex-1" type="submit">수정 완료</button>
#                         <a class="btn-secondary flex-1" href="/employee/detail/{{employee_id}}">취소</a>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
#
#     <div id="toast" class="toast"></div>
#
#     <script>
#         function showToast(message, isError = false) {
#             const toast = document.getElementById('toast');
#             toast.textContent = message;
#             toast.className = isError ? 'toast show error' : 'toast show';
#
#             setTimeout(() => {
#                 toast.className = isError ? 'toast error' : 'toast';
#             }, 2200);
#         }
#
#         async function submitEmployeeEditForm(formElement) {
#             try {
#                 const formData = new FormData(formElement);
#                 const payload = Object.fromEntries(formData.entries());
#
#                 const response = await fetch(formElement.action, {
#                     method: 'POST',
#                     headers: {
#                         'Content-Type': 'application/json',
#                         'Accept': 'application/json',
#                         'X-Requested-With': 'XMLHttpRequest'
#                     },
#                     body: JSON.stringify(payload)
#                 });
#
#                 const result = await response.json();
#
#                 if (!response.ok || !result.success) {
#                     throw new Error(result.message || '수정 처리 중 오류가 발생했습니다.');
#                 }
#
#                 showToast(result.message);
#                 setTimeout(() => {
#                     window.location.href = result.redirectUrl;
#                 }, 500);
#             } catch (error) {
#                 showToast(error.message, true);
#             }
#         }
#
#         document.getElementById('employeeEditForm').addEventListener('submit', async (event) => {
#             event.preventDefault();
#             await submitEmployeeEditForm(event.currentTarget);
#         });
#     </script>
# </body>
# </html>

# %%
# %%writefile templates/employee-message.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>처리 결과</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-mini">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#         </div>
#
#         <div class="panel">
#             <div class="message-wrap">
#                 <h1 class="message-title">{{title}}</h1>
#                 <p class="message-text">{{message}}</p>
#                 <a class="btn" href="/employee/list">목록으로 이동</a>
#             </div>
#         </div>
#     </div>
# </body>
# </html>

# %% [markdown]
# # 토큰 실습

# %%
# %%writefile /content/templates/signup.html
#
# <h1>회원가입</h1>
# <input type="text" id="uId" placeholder="아이디"><br>
# <input type="password" id="uPw" placeholder="비밀번호"><br>
# <input type="text" id="uName" placeholder="이름"><br>
# <button onclick="save()">가입하기</button>
# <script>
#     async function save() {
#         await fetch('/api/signup', {
#             method: 'POST',
#             headers: {'Content-Type': 'application/json'},
#             body: JSON.stringify({userId: uId.value, password: uPw.value, userName: uName.value})
#         });
#         alert('가입 완료'); location.href = '/';
#     }
# </script>
# Out:
# Overwriting /content/templates/signup.html

# %%
# %%writefile /content/templates/login.html
#
# <h1>로그인</h1>
#
# <input type="text" id="uId" placeholder="아이디"><br>
# <input type="password" id="uPw" placeholder="비밀번호"><br>
#
# <button onclick="login()">로그인</button>
# <button onclick="location.href='/signup'">회원가입</button>
#
# <script>
#     async function login() {
#         const res = await fetch('/api/login', {
#             method: 'POST',
#             headers: {'Content-Type': 'application/json'},
#             body: JSON.stringify({userId: uId.value, password: uPw.value})
#         });
#
#         const data = await res.json();
#
#         if(data.success) {
#             localStorage.setItem('myToken', data.token);
#             location.href = '/main';
#         } else {
#             alert('로그인 실패');
#         }
#     }
# </script>
# Out:
# Overwriting /content/templates/login.html

# %%
# %%writefile /content/templates/main.html
#
# <h1>메인 대시보드</h1>
# <p id="welcome"></p>
# <button onclick="localStorage.removeItem('myToken'); location.href='/';">로그아웃</button>
# <hr>
# <h3>지출 내역 (DB에서 비동기 로드)</h3>
# <ul id="list"></ul>
#
# <script>
#     async function init() {
#         const token = localStorage.getItem('myToken');
#         if(!token) { location.href = '/'; return; }
#
#         // 1. 토큰 검증 요청 (헤더에 토큰 실어서 보냄)
#         const authRes = await fetch('/api/verify', {
#             headers: {'Authorization': `Bearer ${token}`}
#         });
#         const authData = await authRes.json();
#
#         if(authData.success) {
#             document.getElementById('welcome').innerText = authData.user.userName + "님 반갑습니다.";
#             loadData(); // 인증 성공 시에만 데이터 불러오기
#         } else {
#             alert('인증이 만료되었습니다.'); location.href = '/';
#         }
#     }
#
#     async function loadData() {
#         const res = await fetch('/api/data');
#         const data = await res.json();
#         const list = document.getElementById('list');
#         data.forEach(item => {
#             const li = document.createElement('li');
#             li.innerText = `${item.date} - ${item.name}: ${item.amount}원`;
#             list.appendChild(li);
#         });
#     }
#
#     init();
# </script>
# Out:
# Overwriting /content/templates/main.html

# %%
# %%writefile /content/server.js
#
# const express = require('express');
# const path = require('path');
# const mysql = require('mysql2/promise');
# const jwt = require('jsonwebtoken');
# const bcrypt = require('bcrypt');
#
# const app = express();
# const PORT = 3000;
# const JWT_SECRET = 'my_super_secret_key'; // 클라이언트와 서버가 공유하는 비밀 열쇠
#
# app.use(express.json());
#
# // MariaDB 연결 설정
# const pool = mysql.createPool({
#     host: 'localhost',
#     user: 'testuser',
#     password: '1234',
#     database: 'testdb'
# });
#
# // [1] 페이지 라우팅: templates 폴더 안의 파일들을 읽어옵니다.
# app.get('/', (req, res) => res.sendFile(path.join(__dirname, 'templates', 'login.html')));
# app.get('/signup', (req, res) => res.sendFile(path.join(__dirname, 'templates', 'signup.html')));
# app.get('/main', (req, res) => res.sendFile(path.join(__dirname, 'templates', 'main.html')));
#
# // [2] API: 회원가입 (비밀번호 암호화 후 DB 저장)
# app.post('/api/signup', async (req, res) => {
#     try {
#         const { userId, password, userName } = req.body;
#         const hashed = await bcrypt.hash(password, 10);
#         await pool.execute('INSERT INTO users (user_id, password, user_name) VALUES (?, ?, ?)', [userId, hashed, userName]);
#         res.json({ success: true });
#     } catch (err) {
#         res.status(500).json({ success: false });
#     }
# });
#
# // [3] API: 로그인 (검증 성공 시 JWT 발급)
# app.post('/api/login', async (req, res) => {
#     try {
#         const { userId, password } = req.body;
#         const [rows] = await pool.execute('SELECT * FROM users WHERE user_id = ?', [userId]);
#         const user = rows[0];
#
#         if (user && await bcrypt.compare(password, user.password)) {
#             // Payload에 유저 정보를 담아 서명함
#             const token = jwt.sign({ userId: user.user_id, userName: user.user_name }, JWT_SECRET, { expiresIn: '1h' });
#             res.json({ success: true, token });
#         } else {
#             res.status(401).json({ success: false });
#         }
#     } catch (err) {
#         res.status(500).json({ success: false });
#     }
# });
#
# // [4] API: JWT 검증 (클라이언트가 보낸 토큰이 진짜인지 확인)
# app.get('/api/verify', (req, res) => {
#     const authHeader = req.headers['authorization'];
#     const token = authHeader && authHeader.split(' ')[1]; // Bearer 문자열 떼어내기
#
#     if (!token) return res.json({ success: false });
#
#     jwt.verify(token, JWT_SECRET, (err, decoded) => {
#         if (err) return res.json({ success: false });
#         res.json({ success: true, user: decoded }); // 유효하면 해독된 유저 정보 응답
#     });
# });
#
# // [5] API: 보호된 데이터 조회
# app.get('/api/data', async (req, res) => {
#     try {
#         const [rows] = await pool.execute('SELECT * FROM spending');
#         res.json(rows);
#     } catch (err) {
#         res.status(500).json([]);
#     }
# });
#
# app.listen(PORT, () => console.log(`서버 실행 중: http://localhost:${PORT}`));
# Out:
# Overwriting /content/server.js

# %% [markdown]
# # 공통

# %%
# !npm init -y
# Out:
# Wrote to /content/package.json:
#
# {
#   "name": "content",
#   "version": "1.0.0",
#   "main": "index.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1",
#     "start": "node server.js"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "dependencies": {
#     "bcrypt": "^6.0.0",
#     "express": "^5.2.1",
#     "jsonwebtoken": "^9.0.3",
#     "mysql2": "^3.20.0"
#   },
#   "devDependencies": {},
#   "description": ""
# }
#
#
#
# ⠙

# %%
# !npm install express mysql2
# Out:
# ⠙⠹⠸⠼⠴⠦⠧
# up to date, audited 94 packages in 1s
# ⠧
# ⠧25 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# found 0 vulnerabilities
# ⠧

# %%
# !npm install express mysql2 jsonwebtoken bcrypt
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 94 packages in 2s
# ⠇
# ⠇25 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# found 0 vulnerabilities
# ⠇

# %%
# !nohup node server.js > server.log 2>&1 &

# %%
# !tail -n 20 server.log
# Out:
# 서버 실행 중: http://localhost:3000

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# changed 1 package in 1s
# ⠼

# %%
# !nohup cloudflared tunnel --url http://localhost:3000 > tunnel.log 2>&1 &

# %%
# !tail -n 20 tunnel.log
# Out:
# 2026-03-20T04:42:12Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-03-20T04:42:12Z INF Requesting new quick Tunnel on trycloudflare.com...

# %%
# !grep -o "https://[a-zA-Z0-9.-]*\.trycloudflare.com" tunnel.log |tail -n 1
# Out:
# https://easier-von-same-fairfield.trycloudflare.com
