# %% [markdown]
# <a href="https://colab.research.google.com/github/minju0236/Hankyung-Bootcamp/blob/main/Day11_1_(260318)_%EC%A7%81%EC%9B%90%EA%B4%80%EB%A6%AC_%EB%B0%8F_%EC%9E%90%EC%9E%AC%EA%B4%80%EB%A6%AC_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 직원관리

# %%
# %%writefile static/style.css
#
# @import url("https://cdn.jsdelivr.net/gh/orioncactus/pretendard@v1.3.9/dist/web/static/pretendard.css");
#
# * {
#     box-sizing: border-box;
# }
#
# html,
# body {
#     margin: 0;
#     padding: 0;
# }
#
# body {
#     background: #f6f8fb;
#     color: #191f28;
#     font-family: "Pretendard", "Noto Sans KR", Arial, sans-serif;
#     line-height: 1.5;
# }
#
# a {
#     color: inherit;
#     text-decoration: none;
# }
#
# button,
# input,
# select,
# textarea {
#     font: inherit;
# }
#
# img {
#     display: block;
# }
#
# .page {
#     max-width: 1280px;
#     margin: 0 auto;
#     padding: 32px 24px 72px;
# }
#
# .page-narrow {
#     max-width: 980px;
# }
#
# .page-mini {
#     max-width: 560px;
# }
#
# .topbar {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     margin-bottom: 28px;
# }
#
# .brand {
#     display: flex;
#     align-items: center;
#     gap: 14px;
# }
#
# .brand-logo {
#     width: 130px;
#     height: auto;
# }
#
# .brand-text {
#     display: flex;
#     flex-direction: column;
#     gap: 2px;
# }
#
# .brand-title {
#     font-size: 14px;
#     font-weight: 700;
#     color: #4e5968;
# }
#
# .brand-subtitle {
#     font-size: 12px;
#     color: #8b95a1;
# }
#
# .topbar-right {
#     display: flex;
#     align-items: center;
#     gap: 10px;
# }
#
# .top-chip {
#     min-height: 38px;
#     padding: 0 14px;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 999px;
#     background: #ffffff;
#     color: #4e5968;
#     border: 1px solid #eef2f6;
#     font-size: 13px;
#     font-weight: 600;
# }
#
# .hero {
#     margin-bottom: 20px;
# }
#
# .hero-title {
#     margin: 0 0 8px;
#     font-size: 36px;
#     line-height: 1.28;
#     letter-spacing: -0.8px;
#     font-weight: 700;
# }
#
# .hero-text {
#     margin: 0;
#     font-size: 15px;
#     color: #8b95a1;
# }
#
# .panel {
#     background: #ffffff;
#     border-radius: 32px;
#     box-shadow: 0 8px 24px rgba(15, 23, 42, 0.05);
#     overflow: hidden;
#     border: 1px solid #eef2f6;
# }
#
# .panel-head {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     padding: 28px 28px 18px;
# }
#
# .panel-title {
#     margin: 0;
#     font-size: 22px;
#     font-weight: 700;
#     letter-spacing: -0.4px;
# }
#
# .panel-text {
#     margin: 4px 0 0;
#     font-size: 14px;
#     color: #8b95a1;
# }
#
# .panel-body {
#     padding: 0 28px 28px;
# }
#
# .btn,
# .btn-secondary,
# .btn-danger,
# .action-link {
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#     min-height: 50px;
#     padding: 0 18px;
#     border-radius: 16px;
#     border: none;
#     cursor: pointer;
#     font-size: 14px;
#     font-weight: 700;
#     white-space: nowrap;
# }
#
# .btn {
#     background: #3182f6;
#     color: #ffffff;
# }
#
# .btn:hover {
#     background: #1b64da;
# }
#
# .btn-secondary {
#     background: #f2f4f6;
#     color: #4e5968;
# }
#
# .btn-secondary:hover {
#     background: #e9ecef;
# }
#
# .btn-danger {
#     background: #f04452;
#     color: #ffffff;
# }
#
# .btn-danger:hover {
#     background: #d92d20;
# }
#
# .flex-1 {
#     flex: 1;
# }
#
# .table-wrap {
#     width: 100%;
#     overflow-x: auto;
# }
#
# table {
#     width: 100%;
#     border-collapse: collapse;
#     table-layout: fixed;
# }
#
# thead th {
#     padding: 16px 10px;
#     background: #fafbfc;
#     border-bottom: 1px solid #eef2f6;
#     font-size: 13px;
#     font-weight: 700;
#     color: #6b7684;
#     text-align: center;
# }
#
# tbody td {
#     padding: 16px 10px;
#     border-bottom: 1px solid #f2f4f6;
#     font-size: 14px;
#     color: #333d4b;
#     text-align: center;
#     vertical-align: middle;
# }
#
# tbody tr:last-child td {
#     border-bottom: none;
# }
#
# .title-cell {
#     text-align: left;
# }
#
# .title-link {
#     font-weight: 700;
#     color: #191f28;
# }
#
# .title-link:hover {
#     color: #3182f6;
# }
#
# .col-id { width: 70px; }
# .col-empno { width: 120px; }
# .col-name { width: 110px; }
# .col-dept { width: 140px; }
# .col-position { width: 90px; }
# .col-status { width: 90px; }
# .col-salary { width: 130px; }
# .col-date { width: 120px; }
# .col-action { width: 84px; }
#
# .action-link {
#     min-height: 36px;
#     padding: 0 12px;
#     border-radius: 12px;
#     font-size: 13px;
# }
#
# .view-link {
#     background: #edf4ff;
#     color: #3182f6;
# }
#
# .edit-link {
#     background: #f2f4f6;
#     color: #4e5968;
# }
#
# .delete-btn {
#     width: 100%;
#     min-height: 36px;
#     padding: 0 12px;
#     border: none;
#     border-radius: 12px;
#     background: #ffe9eb;
#     color: #e11d48;
#     font-size: 13px;
#     font-weight: 700;
#     cursor: pointer;
# }
#
# .inline-form {
#     margin: 0;
#     width: 100%;
# }
#
# .money {
#     white-space: nowrap;
#     font-variant-numeric: tabular-nums;
# }
#
# .empty-box {
#     padding: 64px 20px;
#     text-align: center;
#     color: #8b95a1;
#     font-size: 15px;
#     background: #fbfcfd;
#     border-radius: 22px;
# }
#
# .form-wrap {
#     padding: 28px;
# }
#
# .form-grid {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 20px 18px;
# }
#
# .form-group {
#     min-width: 0;
# }
#
# .form-group.full {
#     grid-column: 1 / -1;
# }
#
# label {
#     display: block;
#     margin-bottom: 10px;
#     font-size: 14px;
#     font-weight: 700;
#     color: #4e5968;
# }
#
# input,
# select,
# textarea {
#     width: 100%;
#     border: 1px solid #e5e8eb;
#     border-radius: 18px;
#     background: #ffffff;
#     color: #191f28;
#     padding: 16px 18px;
#     outline: none;
# }
#
# input:focus,
# select:focus,
# textarea:focus {
#     border-color: #3182f6;
#     box-shadow: 0 0 0 4px rgba(49, 130, 246, 0.12);
# }
#
# textarea {
#     min-height: 180px;
#     line-height: 1.7;
#     resize: vertical;
# }
#
# .button-row {
#     display: flex;
#     gap: 12px;
#     margin-top: 28px;
# }
#
# .summary-strip {
#     display: grid;
#     grid-template-columns: repeat(3, minmax(0, 1fr));
#     gap: 14px;
#     padding: 28px 28px 0;
# }
#
# .summary-card {
#     background: #f9fafb;
#     border-radius: 22px;
#     padding: 18px 20px;
# }
#
# .summary-label {
#     display: block;
#     margin-bottom: 6px;
#     font-size: 13px;
#     font-weight: 700;
#     color: #8b95a1;
# }
#
# .summary-value {
#     font-size: 18px;
#     font-weight: 700;
#     color: #191f28;
#     word-break: break-word;
# }
#
# .detail-wrap {
#     padding: 28px;
# }
#
# .detail-grid {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 16px;
# }
#
# .detail-item {
#     padding: 18px 20px;
#     border: 1px solid #f2f4f6;
#     border-radius: 20px;
#     background: #ffffff;
# }
#
# .detail-item.full {
#     grid-column: 1 / -1;
# }
#
# .detail-label {
#     display: block;
#     margin-bottom: 6px;
#     font-size: 13px;
#     font-weight: 700;
#     color: #8b95a1;
# }
#
# .detail-value {
#     font-size: 15px;
#     color: #191f28;
#     line-height: 1.7;
#     word-break: break-word;
# }
#
# .note-box {
#     margin-top: 16px;
#     padding: 22px;
#     border: 1px solid #f2f4f6;
#     border-radius: 20px;
#     background: #ffffff;
# }
#
# .note-title {
#     margin: 0 0 12px;
#     font-size: 16px;
#     font-weight: 700;
#     color: #191f28;
# }
#
# .note-content {
#     font-size: 15px;
#     color: #333d4b;
#     line-height: 1.8;
#     white-space: pre-wrap;
#     word-break: break-word;
# }
#
# .message-wrap {
#     padding: 40px 28px;
#     text-align: center;
# }
#
# .message-title {
#     margin: 0 0 12px;
#     font-size: 30px;
#     font-weight: 700;
# }
#
# .message-text {
#     margin: 0 0 28px;
#     font-size: 16px;
#     color: #4e5968;
#     line-height: 1.7;
# }
#
# @media (max-width: 980px) {
#     .form-grid,
#     .summary-strip,
#     .detail-grid {
#         grid-template-columns: 1fr;
#     }
# }
#
# @media (max-width: 720px) {
#     .page,
#     .page-narrow,
#     .page-mini {
#         padding: 20px 14px 40px;
#     }
#
#     .topbar {
#         flex-direction: column;
#         align-items: flex-start;
#         gap: 12px;
#     }
#
#     .hero-title {
#         font-size: 28px;
#     }
#
#     .panel-head,
#     .panel-body,
#     .form-wrap,
#     .detail-wrap,
#     .summary-strip,
#     .message-wrap {
#         padding-left: 18px;
#         padding-right: 18px;
#     }
#
#     .button-row {
#         flex-direction: column;
#     }
#
#     .table-wrap table {
#         min-width: 1120px;
#     }
# }
# Out:
# Writing static/style.css

# %%
# %%writefile templates/employee-write.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 등록</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/employee/list">목록</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 등록</h1>
#             <p class="hero-text">신규 직원 정보를 등록합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="form-wrap">
#                 <form action="/employee/write" method="post">
#                     <div class="form-grid">
#                         <div class="form-group">
#                             <label for="emp_no">사번</label>
#                             <input type="text" id="emp_no" name="emp_no" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="name">직원명</label>
#                             <input type="text" id="name" name="name" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="department">부서</label>
#                             <input type="text" id="department" name="department" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="position">직급</label>
#                             <input type="text" id="position" name="position" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="hire_date">입사일</label>
#                             <input type="date" id="hire_date" name="hire_date" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="employment_status">재직상태</label>
#                             <select id="employment_status" name="employment_status" required>
#                                 <option value="재직">재직</option>
#                                 <option value="승진">승진</option>
#                                 <option value="휴직">휴직</option>
#                                 <option value="퇴사">퇴사</option>
#                             </select>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="annual_salary">연봉</label>
#                             <input type="number" id="annual_salary" name="annual_salary" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="tax">세금</label>
#                             <input type="number" id="tax" name="tax" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="bonus">보너스</label>
#                             <input type="number" id="bonus" name="bonus" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="phone">연락처</label>
#                             <input type="text" id="phone" name="phone" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="address">주소</label>
#                             <input type="text" id="address" name="address" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="email">이메일</label>
#                             <input type="email" id="email" name="email" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="hr_note">인사 메모</label>
#                             <textarea id="hr_note" name="hr_note" required></textarea>
#                         </div>
#                     </div>
#
#                     <div class="button-row">
#                         <button class="btn flex-1" type="submit">저장하기</button>
#                         <a class="btn-secondary flex-1" href="/employee/list">취소</a>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Writing templates/employee-write.html

# %%
# %%writefile templates/employee-list.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 목록</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <span class="top-chip">HR Admin</span>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 목록</h1>
#             <p class="hero-text">직원 정보를 조회하고 관리합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="panel-head">
#                 <div>
#                     <h2 class="panel-title">전체 직원</h2>
#                     <p class="panel-text">등록된 직원 데이터를 확인할 수 있습니다.</p>
#                 </div>
#                 <a class="btn" href="/employee/write">직원 등록</a>
#             </div>
#
#             <div class="panel-body">
#                 {{table_section}}
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Writing templates/employee-list.html

# %%
# %%writefile templates/employee-detail.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 상세</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/employee/list">목록</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 상세</h1>
#             <p class="hero-text">직원 인사 정보를 확인합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="summary-strip">
#                 <div class="summary-card">
#                     <span class="summary-label">직원번호</span>
#                     <div class="summary-value">{{employee_id}}</div>
#                 </div>
#                 <div class="summary-card">
#                     <span class="summary-label">직원명</span>
#                     <div class="summary-value">{{name}}</div>
#                 </div>
#                 <div class="summary-card">
#                     <span class="summary-label">등록일시</span>
#                     <div class="summary-value">{{created_at}}</div>
#                 </div>
#             </div>
#
#             <div class="detail-wrap">
#                 <div class="detail-grid">
#                     <div class="detail-item">
#                         <span class="detail-label">사번</span>
#                         <div class="detail-value">{{emp_no}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">부서</span>
#                         <div class="detail-value">{{department}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">직급</span>
#                         <div class="detail-value">{{position}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">입사일</span>
#                         <div class="detail-value">{{hire_date}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">재직상태</span>
#                         <div class="detail-value">{{employment_status}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">연봉</span>
#                         <div class="detail-value money">{{annual_salary}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">세금</span>
#                         <div class="detail-value money">{{tax}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">보너스</span>
#                         <div class="detail-value money">{{bonus}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">연락처</span>
#                         <div class="detail-value">{{phone}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">이메일</span>
#                         <div class="detail-value">{{email}}</div>
#                     </div>
#
#                     <div class="detail-item full">
#                         <span class="detail-label">주소</span>
#                         <div class="detail-value">{{address}}</div>
#                     </div>
#                 </div>
#
#                 <div class="note-box">
#                     <h2 class="note-title">인사 메모</h2>
#                     <div class="note-content">{{hr_note}}</div>
#                 </div>
#
#                 <div class="button-row">
#                     <a class="btn-secondary flex-1" href="/employee/list">목록</a>
#                     <a class="btn flex-1" href="/employee/edit/{{employee_id}}">수정</a>
#                     <form class="inline-form flex-1" action="/employee/delete/{{employee_id}}" method="post" onsubmit="return confirm('정말 삭제하시겠습니까?');">
#                         <button class="btn-danger" type="submit" style="width: 100%;">삭제</button>
#                     </form>
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Writing templates/employee-detail.html

# %%
# %%writefile templates/employee-edit.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>직원 수정</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/employee/detail/{{employee_id}}">상세</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">직원 수정</h1>
#             <p class="hero-text">직원 인사 정보를 수정합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="form-wrap">
#                 <form action="/employee/edit/{{employee_id}}" method="post">
#                     <div class="form-grid">
#                         <div class="form-group">
#                             <label for="emp_no">사번</label>
#                             <input type="text" id="emp_no" name="emp_no" value="{{emp_no}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="name">직원명</label>
#                             <input type="text" id="name" name="name" value="{{name}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="department">부서</label>
#                             <input type="text" id="department" name="department" value="{{department}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="position">직급</label>
#                             <input type="text" id="position" name="position" value="{{position}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="hire_date">입사일</label>
#                             <input type="date" id="hire_date" name="hire_date" value="{{hire_date}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="employment_status">재직상태</label>
#                             <select id="employment_status" name="employment_status" required>
#                                 <option value="재직" {{selected_status_working}}>재직</option>
#                                 <option value="승진" {{selected_status_promoted}}>승진</option>
#                                 <option value="휴직" {{selected_status_leave}}>휴직</option>
#                                 <option value="퇴사" {{selected_status_resigned}}>퇴사</option>
#                             </select>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="annual_salary">연봉</label>
#                             <input type="number" id="annual_salary" name="annual_salary" value="{{annual_salary}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="tax">세금</label>
#                             <input type="number" id="tax" name="tax" value="{{tax}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="bonus">보너스</label>
#                             <input type="number" id="bonus" name="bonus" value="{{bonus}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="phone">연락처</label>
#                             <input type="text" id="phone" name="phone" value="{{phone}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="address">주소</label>
#                             <input type="text" id="address" name="address" value="{{address}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="email">이메일</label>
#                             <input type="email" id="email" name="email" value="{{email}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="hr_note">인사 메모</label>
#                             <textarea id="hr_note" name="hr_note" required>{{hr_note}}</textarea>
#                         </div>
#                     </div>
#
#                     <div class="button-row">
#                         <button class="btn flex-1" type="submit">수정 완료</button>
#                         <a class="btn-secondary flex-1" href="/employee/detail/{{employee_id}}">취소</a>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Writing templates/employee-edit.html

# %%
# %%writefile templates/employee-message.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>처리 결과</title>
#     <link rel="stylesheet" href="/static/style.css">
# </head>
# <body>
#     <div class="page page-mini">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">인사관리</div>
#                     <div class="brand-subtitle">Employee Management</div>
#                 </div>
#             </div>
#         </div>
#
#         <div class="panel">
#             <div class="message-wrap">
#                 <h1 class="message-title">{{title}}</h1>
#                 <p class="message-text">{{message}}</p>
#                 <a class="btn" href="/employee/list">목록으로 이동</a>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Writing templates/employee-message.html

# %%
# %%writefile server.js
#
# const express = require('express');
# const path = require('path');
# const fs = require('fs');
# const mysql = require('mysql2');
#
# const app = express();
# const PORT = 3000;
#
# app.use(express.urlencoded({ extended: true }));
# app.use('/static', express.static(path.join(__dirname, 'static')));
#
# const conn = mysql.createConnection({
#     host: 'localhost',
#     user: 'testuser',
#     password: '1234',
#     database: 'testdb',
#     dateStrings: true
# });
#
# conn.connect((err) => {
#     if (err) {
#         console.error('DB 연결 실패:', err);
#         return;
#     }
#     console.log('DB 연결 성공');
# });
#
# function escapeHtml(value) {
#     if (value === null || value === undefined) {
#         return '';
#     }
#
#     return String(value)
#         .replace(/&/g, '&amp;')
#         .replace(/</g, '&lt;')
#         .replace(/>/g, '&gt;')
#         .replace(/"/g, '&quot;')
#         .replace(/'/g, '&#39;');
# }
#
# function readTemplate(fileName) {
#     const filePath = path.join(__dirname, 'templates', fileName);
#     return fs.readFileSync(filePath, 'utf8');
# }
#
# function renderTemplate(template, data) {
#     let html = template;
#
#     for (const key in data) {
#         const pattern = new RegExp(`{{${key}}}`, 'g');
#         html = html.replace(pattern, data[key]);
#     }
#
#     return html;
# }
#
# function sendMessagePage(res, title, message) {
#     const template = readTemplate('employee-message.html');
#     const html = renderTemplate(template, {
#         title: escapeHtml(title),
#         message: escapeHtml(message)
#     });
#     res.send(html);
# }
#
# function formatMoney(value) {
#     return Number(value).toLocaleString('ko-KR');
# }
#
# function getStatusSelectedMap(status) {
#     return {
#         selected_status_working: status === '재직' ? 'selected' : '',
#         selected_status_promoted: status === '승진' ? 'selected' : '',
#         selected_status_leave: status === '휴직' ? 'selected' : '',
#         selected_status_resigned: status === '퇴사' ? 'selected' : ''
#     };
# }
#
# app.get('/', (req, res) => {
#     res.redirect('/employee/list');
# });
#
# app.get('/employee/list', (req, res) => {
#     const sql = `
#         SELECT
#             employee_id,
#             emp_no,
#             name,
#             department,
#             position,
#             employment_status,
#             annual_salary,
#             DATE_FORMAT(hire_date, '%Y-%m-%d') AS hire_date
#         FROM employee
#         ORDER BY employee_id DESC
#     `;
#
#     conn.query(sql, (err, rows) => {
#         if (err) {
#             console.error('직원 목록 조회 실패:', err);
#             return sendMessagePage(res, '조회 실패', '직원 목록 조회 중 오류가 발생했습니다.');
#         }
#
#         let tableSection = '';
#
#         if (rows.length === 0) {
#             tableSection = `<div class="empty-box">등록된 직원 정보가 없습니다.</div>`;
#         } else {
#             let rowsHtml = '';
#
#             for (let i = 0; i < rows.length; i++) {
#                 rowsHtml += `
#                     <tr>
#                         <td>${rows[i].employee_id}</td>
#                         <td>${escapeHtml(rows[i].emp_no)}</td>
#                         <td class="title-cell">
#                             <a class="title-link" href="/employee/detail/${rows[i].employee_id}">${escapeHtml(rows[i].name)}</a>
#                         </td>
#                         <td>${escapeHtml(rows[i].department)}</td>
#                         <td>${escapeHtml(rows[i].position)}</td>
#                         <td>${escapeHtml(rows[i].employment_status)}</td>
#                         <td class="money">${formatMoney(rows[i].annual_salary)}원</td>
#                         <td>${rows[i].hire_date}</td>
#                         <td>
#                             <a class="action-link view-link" href="/employee/detail/${rows[i].employee_id}">조회</a>
#                         </td>
#                         <td>
#                             <a class="action-link edit-link" href="/employee/edit/${rows[i].employee_id}">수정</a>
#                         </td>
#                         <td>
#                             <form class="inline-form" action="/employee/delete/${rows[i].employee_id}" method="post" onsubmit="return confirm('정말 삭제하시겠습니까?');">
#                                 <button class="delete-btn" type="submit">삭제</button>
#                             </form>
#                         </td>
#                     </tr>
#                 `;
#             }
#
#             tableSection = `
# 					    <div class="table-wrap">
# 					        <table>
# 					            <thead>
# 					                <tr>
# 					                    <th class="col-id">번호</th>
# 					                    <th class="col-empno">사번</th>
# 					                    <th class="col-name">직원명</th>
# 					                    <th class="col-dept">부서</th>
# 					                    <th class="col-position">직급</th>
# 					                    <th class="col-status">상태</th>
# 					                    <th class="col-salary">연봉</th>
# 					                    <th class="col-date">입사일</th>
# 					                    <th class="col-action">조회</th>
# 					                    <th class="col-action">수정</th>
# 					                    <th class="col-action">삭제</th>
# 					                </tr>
# 					            </thead>
# 					            <tbody>
# 					                ${rowsHtml}
# 					            </tbody>
# 					        </table>
# 					    </div>
# 					`;
#         }
#
#         const template = readTemplate('employee-list.html');
#         const html = renderTemplate(template, {
#             table_section: tableSection
#         });
#
#         res.send(html);
#     });
# });
#
# app.get('/employee/write', (req, res) => {
#     res.sendFile(path.join(__dirname, 'templates', 'employee-write.html'));
# });
#
# app.post('/employee/write', (req, res) => {
#     const {
#         emp_no,
#         name,
#         department,
#         position,
#         hire_date,
#         employment_status,
#         annual_salary,
#         tax,
#         bonus,
#         address,
#         phone,
#         email,
#         hr_note
#     } = req.body;
#
#     const sql = `
#         INSERT INTO employee (
#             emp_no,
#             name,
#             department,
#             position,
#             hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note,
#             created_at
#         )
#         VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, CONVERT_TZ(UTC_TIMESTAMP(), '+00:00', '+09:00'))
#     `;
#
#     conn.query(sql, [
#         emp_no,
#         name,
#         department,
#         position,
#         hire_date,
#         employment_status,
#         annual_salary,
#         tax,
#         bonus,
#         address,
#         phone,
#         email,
#         hr_note
#     ], (err) => {
#         if (err) {
#             console.error('직원 정보 저장 실패:', err);
#             return sendMessagePage(res, '저장 실패', '직원 정보 저장 중 오류가 발생했습니다.');
#         }
#
#         res.redirect('/employee/list');
#     });
# });
#
# app.get('/employee/detail/:id', (req, res) => {
#     const employeeId = req.params.id;
#
#     const sql = `
#         SELECT
#             employee_id,
#             emp_no,
#             name,
#             department,
#             position,
#             DATE_FORMAT(hire_date, '%Y-%m-%d') AS hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note,
#             DATE_FORMAT(created_at, '%Y-%m-%d %H:%i:%s') AS created_at
#         FROM employee
#         WHERE employee_id = ?
#     `;
#
#     conn.query(sql, [employeeId], (err, rows) => {
#         if (err) {
#             console.error('직원 상세 조회 실패:', err);
#             return sendMessagePage(res, '조회 실패', '직원 정보 조회 중 오류가 발생했습니다.');
#         }
#
#         if (rows.length === 0) {
#             return sendMessagePage(res, '조회 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         const row = rows[0];
#         const template = readTemplate('employee-detail.html');
#         const html = renderTemplate(template, {
#             employee_id: String(row.employee_id),
#             emp_no: escapeHtml(row.emp_no),
#             name: escapeHtml(row.name),
#             department: escapeHtml(row.department),
#             position: escapeHtml(row.position),
#             hire_date: row.hire_date,
#             employment_status: escapeHtml(row.employment_status),
#             annual_salary: formatMoney(row.annual_salary),
#             tax: formatMoney(row.tax),
#             bonus: formatMoney(row.bonus),
#             address: escapeHtml(row.address),
#             phone: escapeHtml(row.phone),
#             email: escapeHtml(row.email),
#             hr_note: escapeHtml(row.hr_note),
#             created_at: row.created_at
#         });
#
#         res.send(html);
#     });
# });
#
# app.get('/employee/edit/:id', (req, res) => {
#     const employeeId = req.params.id;
#
#     const sql = `
#         SELECT
#             employee_id,
#             emp_no,
#             name,
#             department,
#             position,
#             DATE_FORMAT(hire_date, '%Y-%m-%d') AS hire_date,
#             employment_status,
#             annual_salary,
#             tax,
#             bonus,
#             address,
#             phone,
#             email,
#             hr_note
#         FROM employee
#         WHERE employee_id = ?
#     `;
#
#     conn.query(sql, [employeeId], (err, rows) => {
#         if (err) {
#             console.error('수정 화면 조회 실패:', err);
#             return sendMessagePage(res, '조회 실패', '수정 화면 조회 중 오류가 발생했습니다.');
#         }
#
#         if (rows.length === 0) {
#             return sendMessagePage(res, '조회 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         const row = rows[0];
#         const statusSelectedMap = getStatusSelectedMap(row.employment_status);
#
#         const template = readTemplate('employee-edit.html');
#         const html = renderTemplate(template, {
#             employee_id: String(row.employee_id),
#             emp_no: escapeHtml(row.emp_no),
#             name: escapeHtml(row.name),
#             department: escapeHtml(row.department),
#             position: escapeHtml(row.position),
#             hire_date: row.hire_date,
#             annual_salary: String(row.annual_salary),
#             tax: String(row.tax),
#             bonus: String(row.bonus),
#             address: escapeHtml(row.address),
#             phone: escapeHtml(row.phone),
#             email: escapeHtml(row.email),
#             hr_note: escapeHtml(row.hr_note),
#             selected_status_working: statusSelectedMap.selected_status_working,
#             selected_status_promoted: statusSelectedMap.selected_status_promoted,
#             selected_status_leave: statusSelectedMap.selected_status_leave,
#             selected_status_resigned: statusSelectedMap.selected_status_resigned
#         });
#
#         res.send(html);
#     });
# });
#
# app.post('/employee/edit/:id', (req, res) => {
#     const employeeId = req.params.id;
#     const {
#         emp_no,
#         name,
#         department,
#         position,
#         hire_date,
#         employment_status,
#         annual_salary,
#         tax,
#         bonus,
#         address,
#         phone,
#         email,
#         hr_note
#     } = req.body;
#
#     const sql = `
#         UPDATE employee
#         SET
#             emp_no = ?,
#             name = ?,
#             department = ?,
#             position = ?,
#             hire_date = ?,
#             employment_status = ?,
#             annual_salary = ?,
#             tax = ?,
#             bonus = ?,
#             address = ?,
#             phone = ?,
#             email = ?,
#             hr_note = ?
#         WHERE employee_id = ?
#     `;
#
#     conn.query(sql, [
#         emp_no,
#         name,
#         department,
#         position,
#         hire_date,
#         employment_status,
#         annual_salary,
#         tax,
#         bonus,
#         address,
#         phone,
#         email,
#         hr_note,
#         employeeId
#     ], (err, result) => {
#         if (err) {
#             console.error('직원 정보 수정 실패:', err);
#             return sendMessagePage(res, '수정 실패', '직원 정보 수정 중 오류가 발생했습니다.');
#         }
#
#         if (result.affectedRows === 0) {
#             return sendMessagePage(res, '수정 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         res.redirect('/employee/detail/' + employeeId);
#     });
# });
#
# app.post('/employee/delete/:id', (req, res) => {
#     const employeeId = req.params.id;
#
#     const sql = `
#         DELETE FROM employee
#         WHERE employee_id = ?
#     `;
#
#     conn.query(sql, [employeeId], (err, result) => {
#         if (err) {
#             console.error('직원 정보 삭제 실패:', err);
#             return sendMessagePage(res, '삭제 실패', '직원 정보 삭제 중 오류가 발생했습니다.');
#         }
#
#         if (result.affectedRows === 0) {
#             return sendMessagePage(res, '삭제 실패', '해당 직원 정보가 존재하지 않습니다.');
#         }
#
#         res.redirect('/employee/list');
#     });
# });
#
# app.listen(PORT, () => {
#     console.log('=========================================');
#     console.log(` 인사관리 서버가 포트 ${PORT}에서 작동 중입니다.`);
#     console.log('=========================================');
# });
# Out:
# Writing server.js

# %% [markdown]
# # 자재 관리

# %%
# %%writefile static/style2.css
#
# @import url("https://cdn.jsdelivr.net/gh/orioncactus/pretendard@v1.3.9/dist/web/static/pretendard.css");
#
# * {
#     box-sizing: border-box;
# }
#
# html,
# body {
#     margin: 0;
#     padding: 0;
# }
#
# body {
#     background: #f6f8fb;
#     color: #191f28;
#     font-family: "Pretendard", "Noto Sans KR", Arial, sans-serif;
#     line-height: 1.5;
# }
#
# a {
#     color: inherit;
#     text-decoration: none;
# }
#
# button,
# input,
# select,
# textarea {
#     font: inherit;
# }
#
# img {
#     display: block;
# }
#
# .page {
#     max-width: 1280px;
#     margin: 0 auto;
#     padding: 32px 24px 72px;
# }
#
# .page-narrow {
#     max-width: 980px;
# }
#
# .page-mini {
#     max-width: 560px;
# }
#
# .topbar {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     margin-bottom: 28px;
# }
#
# .brand {
#     display: flex;
#     align-items: center;
#     gap: 14px;
# }
#
# .brand-logo {
#     width: 130px;
#     height: auto;
# }
#
# .brand-text {
#     display: flex;
#     flex-direction: column;
#     gap: 2px;
# }
#
# .brand-title {
#     font-size: 14px;
#     font-weight: 700;
#     color: #4e5968;
# }
#
# .brand-subtitle {
#     font-size: 12px;
#     color: #8b95a1;
# }
#
# .topbar-right {
#     display: flex;
#     align-items: center;
#     gap: 10px;
# }
#
# .top-chip {
#     min-height: 38px;
#     padding: 0 14px;
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#     border-radius: 999px;
#     background: #ffffff;
#     color: #4e5968;
#     border: 1px solid #eef2f6;
#     font-size: 13px;
#     font-weight: 600;
# }
#
# .hero {
#     margin-bottom: 20px;
# }
#
# .hero-title {
#     margin: 0 0 8px;
#     font-size: 36px;
#     line-height: 1.28;
#     letter-spacing: -0.8px;
#     font-weight: 700;
# }
#
# .hero-text {
#     margin: 0;
#     font-size: 15px;
#     color: #8b95a1;
# }
#
# .panel {
#     background: #ffffff;
#     border-radius: 32px;
#     box-shadow: 0 8px 24px rgba(15, 23, 42, 0.05);
#     overflow: hidden;
#     border: 1px solid #eef2f6;
# }
#
# .panel-head {
#     display: flex;
#     align-items: center;
#     justify-content: space-between;
#     padding: 28px 28px 18px;
# }
#
# .panel-title {
#     margin: 0;
#     font-size: 22px;
#     font-weight: 700;
#     letter-spacing: -0.4px;
# }
#
# .panel-text {
#     margin: 4px 0 0;
#     font-size: 14px;
#     color: #8b95a1;
# }
#
# .panel-body {
#     padding: 0 28px 28px;
# }
#
# .btn,
# .btn-secondary,
# .btn-danger,
# .action-link {
#     display: inline-flex;
#     align-items: center;
#     justify-content: center;
#     min-height: 50px;
#     padding: 0 18px;
#     border-radius: 16px;
#     border: none;
#     cursor: pointer;
#     font-size: 14px;
#     font-weight: 700;
#     white-space: nowrap;
# }
#
# .btn {
#     background: #3182f6;
#     color: #ffffff;
# }
#
# .btn:hover {
#     background: #1b64da;
# }
#
# .btn-secondary {
#     background: #f2f4f6;
#     color: #4e5968;
# }
#
# .btn-secondary:hover {
#     background: #e9ecef;
# }
#
# .btn-danger {
#     background: #f04452;
#     color: #ffffff;
# }
#
# .btn-danger:hover {
#     background: #d92d20;
# }
#
# .flex-1 {
#     flex: 1;
# }
#
# .table-wrap {
#     width: 100%;
#     overflow-x: auto;
# }
#
# table {
#     width: 100%;
#     border-collapse: collapse;
#     table-layout: fixed;
# }
#
# thead th {
#     padding: 16px 10px;
#     background: #fafbfc;
#     border-bottom: 1px solid #eef2f6;
#     font-size: 13px;
#     font-weight: 700;
#     color: #6b7684;
#     text-align: center;
# }
#
# tbody td {
#     padding: 16px 10px;
#     border-bottom: 1px solid #f2f4f6;
#     font-size: 14px;
#     color: #333d4b;
#     text-align: center;
#     vertical-align: middle;
# }
#
# tbody tr:last-child td {
#     border-bottom: none;
# }
#
# .title-cell {
#     text-align: left;
# }
#
# .title-link {
#     font-weight: 700;
#     color: #191f28;
# }
#
# .title-link:hover {
#     color: #3182f6;
# }
#
# .col-id { width: 70px; }
# .col-code { width: 140px; }
# .col-name { width: 180px; }
# .col-category { width: 120px; }
# .col-unit { width: 80px; }
# .col-stock { width: 100px; }
# .col-status { width: 90px; }
# .col-price { width: 120px; }
# .col-date { width: 120px; }
# .col-action { width: 84px; }
#
# .action-link {
#     min-height: 36px;
#     padding: 0 12px;
#     border-radius: 12px;
#     font-size: 13px;
# }
#
# .view-link {
#     background: #edf4ff;
#     color: #3182f6;
# }
#
# .edit-link {
#     background: #f2f4f6;
#     color: #4e5968;
# }
#
# .delete-btn {
#     width: 100%;
#     min-height: 36px;
#     padding: 0 12px;
#     border: none;
#     border-radius: 12px;
#     background: #ffe9eb;
#     color: #e11d48;
#     font-size: 13px;
#     font-weight: 700;
#     cursor: pointer;
# }
#
# .inline-form {
#     margin: 0;
#     width: 100%;
# }
#
# .money {
#     white-space: nowrap;
#     font-variant-numeric: tabular-nums;
# }
#
# .empty-box {
#     padding: 64px 20px;
#     text-align: center;
#     color: #8b95a1;
#     font-size: 15px;
#     background: #fbfcfd;
#     border-radius: 22px;
# }
#
# .form-wrap {
#     padding: 28px;
# }
#
# .form-grid {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 20px 18px;
# }
#
# .form-group {
#     min-width: 0;
# }
#
# .form-group.full {
#     grid-column: 1 / -1;
# }
#
# label {
#     display: block;
#     margin-bottom: 10px;
#     font-size: 14px;
#     font-weight: 700;
#     color: #4e5968;
# }
#
# input,
# select,
# textarea {
#     width: 100%;
#     border: 1px solid #e5e8eb;
#     border-radius: 18px;
#     background: #ffffff;
#     color: #191f28;
#     padding: 16px 18px;
#     outline: none;
# }
#
# input:focus,
# select:focus,
# textarea:focus {
#     border-color: #3182f6;
#     box-shadow: 0 0 0 4px rgba(49, 130, 246, 0.12);
# }
#
# textarea {
#     min-height: 180px;
#     line-height: 1.7;
#     resize: vertical;
# }
#
# .button-row {
#     display: flex;
#     gap: 12px;
#     margin-top: 28px;
# }
#
# .summary-strip {
#     display: grid;
#     grid-template-columns: repeat(3, minmax(0, 1fr));
#     gap: 14px;
#     padding: 28px 28px 0;
# }
#
# .summary-card {
#     background: #f9fafb;
#     border-radius: 22px;
#     padding: 18px 20px;
# }
#
# .summary-label {
#     display: block;
#     margin-bottom: 6px;
#     font-size: 13px;
#     font-weight: 700;
#     color: #8b95a1;
# }
#
# .summary-value {
#     font-size: 18px;
#     font-weight: 700;
#     color: #191f28;
#     word-break: break-word;
# }
#
# .detail-wrap {
#     padding: 28px;
# }
#
# .detail-grid {
#     display: grid;
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#     gap: 16px;
# }
#
# .detail-item {
#     padding: 18px 20px;
#     border: 1px solid #f2f4f6;
#     border-radius: 20px;
#     background: #ffffff;
# }
#
# .detail-item.full {
#     grid-column: 1 / -1;
# }
#
# .detail-label {
#     display: block;
#     margin-bottom: 6px;
#     font-size: 13px;
#     font-weight: 700;
#     color: #8b95a1;
# }
#
# .detail-value {
#     font-size: 15px;
#     color: #191f28;
#     line-height: 1.7;
#     word-break: break-word;
# }
#
# .note-box {
#     margin-top: 16px;
#     padding: 22px;
#     border: 1px solid #f2f4f6;
#     border-radius: 20px;
#     background: #ffffff;
# }
#
# .note-title {
#     margin: 0 0 12px;
#     font-size: 16px;
#     font-weight: 700;
#     color: #191f28;
# }
#
# .note-content {
#     font-size: 15px;
#     color: #333d4b;
#     line-height: 1.8;
#     white-space: pre-wrap;
#     word-break: break-word;
# }
#
# .message-wrap {
#     padding: 40px 28px;
#     text-align: center;
# }
#
# .message-title {
#     margin: 0 0 12px;
#     font-size: 30px;
#     font-weight: 700;
# }
#
# .message-text {
#     margin: 0 0 28px;
#     font-size: 16px;
#     color: #4e5968;
#     line-height: 1.7;
# }
#
# @media (max-width: 980px) {
#     .form-grid,
#     .summary-strip,
#     .detail-grid {
#         grid-template-columns: 1fr;
#     }
# }
#
# @media (max-width: 720px) {
#     .page,
#     .page-narrow,
#     .page-mini {
#         padding: 20px 14px 40px;
#     }
#
#     .topbar {
#         flex-direction: column;
#         align-items: flex-start;
#         gap: 12px;
#     }
#
#     .hero-title {
#         font-size: 28px;
#     }
#
#     .panel-head,
#     .panel-body,
#     .form-wrap,
#     .detail-wrap,
#     .summary-strip,
#     .message-wrap {
#         padding-left: 18px;
#         padding-right: 18px;
#     }
#
#     .button-row {
#         flex-direction: column;
#     }
#
#     .table-wrap table {
#         min-width: 1220px;
#     }
# }
# Out:
# Overwriting static/style2.css

# %%
# %%writefile templates/material-list.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>자재 목록</title>
#     <link rel="stylesheet" href="/static/style2.css">
# </head>
# <body>
#     <div class="page">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">자재관리</div>
#                     <div class="brand-subtitle">Material Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <span class="top-chip">SCM Admin</span>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">자재 목록</h1>
#             <p class="hero-text">자재 정보를 조회하고 관리합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="panel-head">
#                 <div>
#                     <h2 class="panel-title">전체 자재</h2>
#                     <p class="panel-text">등록된 자재 데이터를 확인할 수 있습니다.</p>
#                 </div>
#                 <a class="btn" href="/material/write">자재 등록</a>
#             </div>
#
#             <div class="panel-body">
#                 {{table_section}}
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Overwriting templates/material-list.html

# %%
# %%writefile templates/material-write.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>자재 등록</title>
#     <link rel="stylesheet" href="/static/style2.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">자재관리</div>
#                     <div class="brand-subtitle">Material Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/material/list">목록</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">자재 등록</h1>
#             <p class="hero-text">신규 자재 정보를 등록합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="form-wrap">
#                 <form action="/material/write" method="post">
#                     <div class="form-grid">
#                         <div class="form-group">
#                             <label for="material_code">자재코드</label>
#                             <input type="text" id="material_code" name="material_code" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="material_name">자재명</label>
#                             <input type="text" id="material_name" name="material_name" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="category">분류</label>
#                             <input type="text" id="category" name="category" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="specification">규격</label>
#                             <input type="text" id="specification" name="specification" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="unit">단위</label>
#                             <input type="text" id="unit" name="unit" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="unit_price">단가</label>
#                             <input type="number" id="unit_price" name="unit_price" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="stock_qty">현재고</label>
#                             <input type="number" id="stock_qty" name="stock_qty" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="safety_stock">안전재고</label>
#                             <input type="number" id="safety_stock" name="safety_stock" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="supplier_name">공급업체</label>
#                             <input type="text" id="supplier_name" name="supplier_name" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="warehouse_location">창고위치</label>
#                             <input type="text" id="warehouse_location" name="warehouse_location" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="inbound_date">최근입고일</label>
#                             <input type="date" id="inbound_date" name="inbound_date" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="material_status">자재상태</label>
#                             <select id="material_status" name="material_status" required>
#                                 <option value="정상">정상</option>
#                                 <option value="부족">부족</option>
#                                 <option value="발주중">발주중</option>
#                                 <option value="단종">단종</option>
#                             </select>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="manager_name">담당자명</label>
#                             <input type="text" id="manager_name" name="manager_name" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="manager_phone">담당자 연락처</label>
#                             <input type="text" id="manager_phone" name="manager_phone" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="note">자재 메모</label>
#                             <textarea id="note" name="note" required></textarea>
#                         </div>
#                     </div>
#
#                     <div class="button-row">
#                         <button class="btn flex-1" type="submit">저장하기</button>
#                         <a class="btn-secondary flex-1" href="/material/list">취소</a>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Overwriting templates/material-write.html

# %%
# %%writefile templates/material-detail.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>자재 상세</title>
#     <link rel="stylesheet" href="/static/style2.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">자재관리</div>
#                     <div class="brand-subtitle">Material Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/material/list">목록</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">자재 상세</h1>
#             <p class="hero-text">자재 세부 정보를 확인합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="summary-strip">
#                 <div class="summary-card">
#                     <span class="summary-label">자재번호</span>
#                     <div class="summary-value">{{material_id}}</div>
#                 </div>
#                 <div class="summary-card">
#                     <span class="summary-label">자재명</span>
#                     <div class="summary-value">{{material_name}}</div>
#                 </div>
#                 <div class="summary-card">
#                     <span class="summary-label">등록일시</span>
#                     <div class="summary-value">{{created_at}}</div>
#                 </div>
#             </div>
#
#             <div class="detail-wrap">
#                 <div class="detail-grid">
#                     <div class="detail-item">
#                         <span class="detail-label">자재코드</span>
#                         <div class="detail-value">{{material_code}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">분류</span>
#                         <div class="detail-value">{{category}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">규격</span>
#                         <div class="detail-value">{{specification}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">단위</span>
#                         <div class="detail-value">{{unit}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">단가</span>
#                         <div class="detail-value money">{{unit_price}} 원</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">현재고</span>
#                         <div class="detail-value">{{stock_qty}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">안전재고</span>
#                         <div class="detail-value">{{safety_stock}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">공급업체</span>
#                         <div class="detail-value">{{supplier_name}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">창고위치</span>
#                         <div class="detail-value">{{warehouse_location}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">최근입고일</span>
#                         <div class="detail-value">{{inbound_date}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">자재상태</span>
#                         <div class="detail-value">{{material_status}}</div>
#                     </div>
#
#                     <div class="detail-item">
#                         <span class="detail-label">담당자명</span>
#                         <div class="detail-value">{{manager_name}}</div>
#                     </div>
#
#                     <div class="detail-item full">
#                         <span class="detail-label">담당자 연락처</span>
#                         <div class="detail-value">{{manager_phone}}</div>
#                     </div>
#                 </div>
#
#                 <div class="note-box">
#                     <h2 class="note-title">자재 메모</h2>
#                     <div class="note-content">{{note}}</div>
#                 </div>
#
#                 <div class="button-row">
#                     <a class="btn-secondary flex-1" href="/material/list">목록</a>
#                     <a class="btn flex-1" href="/material/edit/{{material_id}}">수정</a>
#                     <form class="inline-form flex-1" action="/material/delete/{{material_id}}" method="post" onsubmit="return confirm('정말 삭제하시겠습니까?');">
#                         <button class="btn-danger" type="submit" style="width: 100%;">삭제</button>
#                     </form>
#                 </div>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Overwriting templates/material-detail.html

# %%
# %%writefile templates/material-edit.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>자재 수정</title>
#     <link rel="stylesheet" href="/static/style2.css">
# </head>
# <body>
#     <div class="page page-narrow">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">자재관리</div>
#                     <div class="brand-subtitle">Material Management</div>
#                 </div>
#             </div>
#             <div class="topbar-right">
#                 <a class="top-chip" href="/material/detail/{{material_id}}">상세</a>
#             </div>
#         </div>
#
#         <div class="hero">
#             <h1 class="hero-title">자재 수정</h1>
#             <p class="hero-text">자재 정보를 수정합니다.</p>
#         </div>
#
#         <div class="panel">
#             <div class="form-wrap">
#                 <form action="/material/edit/{{material_id}}" method="post">
#                     <div class="form-grid">
#                         <div class="form-group">
#                             <label for="material_code">자재코드</label>
#                             <input type="text" id="material_code" name="material_code" value="{{material_code}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="material_name">자재명</label>
#                             <input type="text" id="material_name" name="material_name" value="{{material_name}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="category">분류</label>
#                             <input type="text" id="category" name="category" value="{{category}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="specification">규격</label>
#                             <input type="text" id="specification" name="specification" value="{{specification}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="unit">단위</label>
#                             <input type="text" id="unit" name="unit" value="{{unit}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="unit_price">단가</label>
#                             <input type="number" id="unit_price" name="unit_price" value="{{unit_price}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="stock_qty">현재고</label>
#                             <input type="number" id="stock_qty" name="stock_qty" value="{{stock_qty}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="safety_stock">안전재고</label>
#                             <input type="number" id="safety_stock" name="safety_stock" value="{{safety_stock}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="supplier_name">공급업체</label>
#                             <input type="text" id="supplier_name" name="supplier_name" value="{{supplier_name}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="warehouse_location">창고위치</label>
#                             <input type="text" id="warehouse_location" name="warehouse_location" value="{{warehouse_location}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="inbound_date">최근입고일</label>
#                             <input type="date" id="inbound_date" name="inbound_date" value="{{inbound_date}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="material_status">자재상태</label>
#                             <select id="material_status" name="material_status" required>
#                                 <option value="정상" {{selected_status_normal}}>정상</option>
#                                 <option value="부족" {{selected_status_shortage}}>부족</option>
#                                 <option value="발주중" {{selected_status_ordering}}>발주중</option>
#                                 <option value="단종" {{selected_status_discontinued}}>단종</option>
#                             </select>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="manager_name">담당자명</label>
#                             <input type="text" id="manager_name" name="manager_name" value="{{manager_name}}" required>
#                         </div>
#
#                         <div class="form-group">
#                             <label for="manager_phone">담당자 연락처</label>
#                             <input type="text" id="manager_phone" name="manager_phone" value="{{manager_phone}}" required>
#                         </div>
#
#                         <div class="form-group full">
#                             <label for="note">자재 메모</label>
#                             <textarea id="note" name="note" required>{{note}}</textarea>
#                         </div>
#                     </div>
#
#                     <div class="button-row">
#                         <button class="btn flex-1" type="submit">수정 완료</button>
#                         <a class="btn-secondary flex-1" href="/material/detail/{{material_id}}">취소</a>
#                     </div>
#                 </form>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Overwriting templates/material-edit.html

# %%
# %%writefile templates/material-message.html
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>처리 결과</title>
#     <link rel="stylesheet" href="/static/style2.css">
# </head>
# <body>
#     <div class="page page-mini">
#         <div class="topbar">
#             <div class="brand">
#                 <img class="brand-logo" src="/static/images/tossbank-logo.png" alt="tossbank">
#                 <div class="brand-text">
#                     <div class="brand-title">자재관리</div>
#                     <div class="brand-subtitle">Material Management</div>
#                 </div>
#             </div>
#         </div>
#
#         <div class="panel">
#             <div class="message-wrap">
#                 <h1 class="message-title">{{title}}</h1>
#                 <p class="message-text">{{message}}</p>
#                 <a class="btn" href="/material/list">목록으로 이동</a>
#             </div>
#         </div>
#     </div>
# </body>
# </html>
# Out:
# Overwriting templates/material-message.html

# %%
# %%writefile server.js
#
# const express = require('express');
# const path = require('path');
# const fs = require('fs');
# const mysql = require('mysql2');
#
# const app = express();
# const PORT = 3000;
#
# app.use(express.urlencoded({ extended: true }));
# app.use('/static', express.static(path.join(__dirname, 'static')));
#
# const conn = mysql.createConnection({
#     host: 'localhost',
#     user: 'testuser',
#     password: '1234',
#     database: 'testdb',
#     dateStrings: true
# });
#
# conn.connect((err) => {
#     if (err) {
#         console.error('DB 연결 실패:', err);
#         return;
#     }
#     console.log('DB 연결 성공');
# });
#
# function escapeHtml(value) {
#     if (value === null || value === undefined) {
#         return '';
#     }
#
#     return String(value)
#         .replace(/&/g, '&amp;')
#         .replace(/</g, '&lt;')
#         .replace(/>/g, '&gt;')
#         .replace(/"/g, '&quot;')
#         .replace(/'/g, '&#39;');
# }
#
# function readTemplate(fileName) {
#     const filePath = path.join(__dirname, 'templates', fileName);
#     return fs.readFileSync(filePath, 'utf8');
# }
#
# function renderTemplate(template, data) {
#     let html = template;
#
#     for (const key in data) {
#         const pattern = new RegExp(`{{${key}}}`, 'g');
#         html = html.replace(pattern, data[key]);
#     }
#
#     return html;
# }
#
# function sendMessagePage(res, title, message) {
#     const template = readTemplate('material-message.html');
#     const html = renderTemplate(template, {
#         title: escapeHtml(title),
#         message: escapeHtml(message)
#     });
#     res.send(html);
# }
#
# function formatMoney(value) {
#     return Number(value).toLocaleString('ko-KR');
# }
#
# function getMaterialStatusSelectedMap(status) {
#     return {
#         selected_status_normal: status === '정상' ? 'selected' : '',
#         selected_status_shortage: status === '부족' ? 'selected' : '',
#         selected_status_ordering: status === '발주중' ? 'selected' : '',
#         selected_status_discontinued: status === '단종' ? 'selected' : ''
#     };
# }
#
# app.get('/', (req, res) => {
#     res.redirect('/material/list');
# });
#
# app.get('/material/list', (req, res) => {
#     const sql = `
#         SELECT
#             material_id,
#             material_code,
#             material_name,
#             category,
#             unit,
#             stock_qty,
#             material_status,
#             unit_price,
#             DATE_FORMAT(inbound_date, '%Y-%m-%d') AS inbound_date
#         FROM material
#         ORDER BY material_id DESC
#     `;
#
#     conn.query(sql, (err, rows) => {
#         if (err) {
#             console.error('자재 목록 조회 실패:', err);
#             return sendMessagePage(res, '조회 실패', '자재 목록 조회 중 오류가 발생했습니다.');
#         }
#
#         let tableSection = '';
#
#         if (rows.length === 0) {
#             tableSection = `<div class="empty-box">등록된 자재 정보가 없습니다.</div>`;
#         } else {
#             let rowsHtml = '';
#
#             for (let i = 0; i < rows.length; i++) {
#                 rowsHtml += `
#                     <tr>
#                         <td>${rows[i].material_id}</td>
#                         <td>${escapeHtml(rows[i].material_code)}</td>
#                         <td class="title-cell">
#                             <a class="title-link" href="/material/detail/${rows[i].material_id}">${escapeHtml(rows[i].material_name)}</a>
#                         </td>
#                         <td>${escapeHtml(rows[i].category)}</td>
#                         <td>${escapeHtml(rows[i].unit)}</td>
#                         <td>${escapeHtml(String(rows[i].stock_qty))}</td>
#                         <td>${escapeHtml(rows[i].material_status)}</td>
#                         <td class="money">${formatMoney(rows[i].unit_price)}원</td>
#                         <td>${rows[i].inbound_date}</td>
#                         <td>
#                             <a class="action-link view-link" href="/material/detail/${rows[i].material_id}">조회</a>
#                         </td>
#                         <td>
#                             <a class="action-link edit-link" href="/material/edit/${rows[i].material_id}">수정</a>
#                         </td>
#                         <td>
#                             <form class="inline-form" action="/material/delete/${rows[i].material_id}" method="post" onsubmit="return confirm('정말 삭제하시겠습니까?');">
#                                 <button class="delete-btn" type="submit">삭제</button>
#                             </form>
#                         </td>
#                     </tr>
#                 `;
#             }
#
#             tableSection = `
#                 <div class="table-wrap">
#                     <table>
#                         <thead>
#                             <tr>
#                                 <th class="col-id">번호</th>
#                                 <th class="col-code">자재코드</th>
#                                 <th class="col-name">자재명</th>
#                                 <th class="col-category">분류</th>
#                                 <th class="col-unit">단위</th>
#                                 <th class="col-stock">현재고</th>
#                                 <th class="col-status">상태</th>
#                                 <th class="col-price">단가</th>
#                                 <th class="col-date">최근입고일</th>
#                                 <th class="col-action">조회</th>
#                                 <th class="col-action">수정</th>
#                                 <th class="col-action">삭제</th>
#                             </tr>
#                         </thead>
#                         <tbody>
#                             ${rowsHtml}
#                         </tbody>
#                     </table>
#                 </div>
#             `;
#         }
#
#         const template = readTemplate('material-list.html');
#         const html = renderTemplate(template, {
#             table_section: tableSection
#         });
#
#         res.send(html);
#     });
# });
#
# app.get('/material/write', (req, res) => {
#     res.sendFile(path.join(__dirname, 'templates', 'material-write.html'));
# });
#
# app.post('/material/write', (req, res) => {
#     const {
#         material_code,
#         material_name,
#         category,
#         specification,
#         unit,
#         unit_price,
#         stock_qty,
#         safety_stock,
#         supplier_name,
#         warehouse_location,
#         inbound_date,
#         material_status,
#         manager_name,
#         manager_phone,
#         note
#     } = req.body;
#
#     const sql = `
#         INSERT INTO material (
#             material_code,
#             material_name,
#             category,
#             specification,
#             unit,
#             unit_price,
#             stock_qty,
#             safety_stock,
#             supplier_name,
#             warehouse_location,
#             inbound_date,
#             material_status,
#             manager_name,
#             manager_phone,
#             note,
#             created_at
#         )
#         VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, CONVERT_TZ(UTC_TIMESTAMP(), '+00:00', '+09:00'))
#     `;
#
#     conn.query(sql, [
#         material_code,
#         material_name,
#         category,
#         specification,
#         unit,
#         unit_price,
#         stock_qty,
#         safety_stock,
#         supplier_name,
#         warehouse_location,
#         inbound_date,
#         material_status,
#         manager_name,
#         manager_phone,
#         note
#     ], (err) => {
#         if (err) {
#             console.error('자재 정보 저장 실패:', err);
#             return sendMessagePage(res, '저장 실패', '자재 정보 저장 중 오류가 발생했습니다.');
#         }
#
#         res.redirect('/material/list');
#     });
# });
#
# app.get('/material/detail/:id', (req, res) => {
#     const materialId = req.params.id;
#
#     const sql = `
#         SELECT
#             material_id,
#             material_code,
#             material_name,
#             category,
#             specification,
#             unit,
#             unit_price,
#             stock_qty,
#             safety_stock,
#             supplier_name,
#             warehouse_location,
#             DATE_FORMAT(inbound_date, '%Y-%m-%d') AS inbound_date,
#             material_status,
#             manager_name,
#             manager_phone,
#             note,
#             DATE_FORMAT(created_at, '%Y-%m-%d %H:%i:%s') AS created_at
#         FROM material
#         WHERE material_id = ?
#     `;
#
#     conn.query(sql, [materialId], (err, rows) => {
#         if (err) {
#             console.error('자재 상세 조회 실패:', err);
#             return sendMessagePage(res, '조회 실패', '자재 정보 조회 중 오류가 발생했습니다.');
#         }
#
#         if (rows.length === 0) {
#             return sendMessagePage(res, '조회 실패', '해당 자재 정보가 존재하지 않습니다.');
#         }
#
#         const row = rows[0];
#         const template = readTemplate('material-detail.html');
#         const html = renderTemplate(template, {
#             material_id: String(row.material_id),
#             material_code: escapeHtml(row.material_code),
#             material_name: escapeHtml(row.material_name),
#             category: escapeHtml(row.category),
#             specification: escapeHtml(row.specification),
#             unit: escapeHtml(row.unit),
#             unit_price: formatMoney(row.unit_price),
#             stock_qty: escapeHtml(String(row.stock_qty)),
#             safety_stock: escapeHtml(String(row.safety_stock)),
#             supplier_name: escapeHtml(row.supplier_name),
#             warehouse_location: escapeHtml(row.warehouse_location),
#             inbound_date: row.inbound_date,
#             material_status: escapeHtml(row.material_status),
#             manager_name: escapeHtml(row.manager_name),
#             manager_phone: escapeHtml(row.manager_phone),
#             note: escapeHtml(row.note),
#             created_at: row.created_at
#         });
#
#         res.send(html);
#     });
# });
#
# app.get('/material/edit/:id', (req, res) => {
#     const materialId = req.params.id;
#
#     const sql = `
#         SELECT
#             material_id,
#             material_code,
#             material_name,
#             category,
#             specification,
#             unit,
#             unit_price,
#             stock_qty,
#             safety_stock,
#             supplier_name,
#             warehouse_location,
#             DATE_FORMAT(inbound_date, '%Y-%m-%d') AS inbound_date,
#             material_status,
#             manager_name,
#             manager_phone,
#             note
#         FROM material
#         WHERE material_id = ?
#     `;
#
#     conn.query(sql, [materialId], (err, rows) => {
#         if (err) {
#             console.error('자재 수정 화면 조회 실패:', err);
#             return sendMessagePage(res, '조회 실패', '수정 화면 조회 중 오류가 발생했습니다.');
#         }
#
#         if (rows.length === 0) {
#             return sendMessagePage(res, '조회 실패', '해당 자재 정보가 존재하지 않습니다.');
#         }
#
#         const row = rows[0];
#         const statusSelectedMap = getMaterialStatusSelectedMap(row.material_status);
#
#         const template = readTemplate('material-edit.html');
#         const html = renderTemplate(template, {
#             material_id: String(row.material_id),
#             material_code: escapeHtml(row.material_code),
#             material_name: escapeHtml(row.material_name),
#             category: escapeHtml(row.category),
#             specification: escapeHtml(row.specification),
#             unit: escapeHtml(row.unit),
#             unit_price: String(row.unit_price),
#             stock_qty: String(row.stock_qty),
#             safety_stock: String(row.safety_stock),
#             supplier_name: escapeHtml(row.supplier_name),
#             warehouse_location: escapeHtml(row.warehouse_location),
#             inbound_date: row.inbound_date,
#             manager_name: escapeHtml(row.manager_name),
#             manager_phone: escapeHtml(row.manager_phone),
#             note: escapeHtml(row.note),
#             selected_status_normal: statusSelectedMap.selected_status_normal,
#             selected_status_shortage: statusSelectedMap.selected_status_shortage,
#             selected_status_ordering: statusSelectedMap.selected_status_ordering,
#             selected_status_discontinued: statusSelectedMap.selected_status_discontinued
#         });
#
#         res.send(html);
#     });
# });
#
# app.post('/material/edit/:id', (req, res) => {
#     const materialId = req.params.id;
#     const {
#         material_code,
#         material_name,
#         category,
#         specification,
#         unit,
#         unit_price,
#         stock_qty,
#         safety_stock,
#         supplier_name,
#         warehouse_location,
#         inbound_date,
#         material_status,
#         manager_name,
#         manager_phone,
#         note
#     } = req.body;
#
#     const sql = `
#         UPDATE material
#         SET
#             material_code = ?,
#             material_name = ?,
#             category = ?,
#             specification = ?,
#             unit = ?,
#             unit_price = ?,
#             stock_qty = ?,
#             safety_stock = ?,
#             supplier_name = ?,
#             warehouse_location = ?,
#             inbound_date = ?,
#             material_status = ?,
#             manager_name = ?,
#             manager_phone = ?,
#             note = ?
#         WHERE material_id = ?
#     `;
#
#     conn.query(sql, [
#         material_code,
#         material_name,
#         category,
#         specification,
#         unit,
#         unit_price,
#         stock_qty,
#         safety_stock,
#         supplier_name,
#         warehouse_location,
#         inbound_date,
#         material_status,
#         manager_name,
#         manager_phone,
#         note,
#         materialId
#     ], (err, result) => {
#         if (err) {
#             console.error('자재 정보 수정 실패:', err);
#             return sendMessagePage(res, '수정 실패', '자재 정보 수정 중 오류가 발생했습니다.');
#         }
#
#         if (result.affectedRows === 0) {
#             return sendMessagePage(res, '수정 실패', '해당 자재 정보가 존재하지 않습니다.');
#         }
#
#         res.redirect('/material/detail/' + materialId);
#     });
# });
#
# app.post('/material/delete/:id', (req, res) => {
#     const materialId = req.params.id;
#
#     const sql = `
#         DELETE FROM material
#         WHERE material_id = ?
#     `;
#
#     conn.query(sql, [materialId], (err, result) => {
#         if (err) {
#             console.error('자재 정보 삭제 실패:', err);
#             return sendMessagePage(res, '삭제 실패', '자재 정보 삭제 중 오류가 발생했습니다.');
#         }
#
#         if (result.affectedRows === 0) {
#             return sendMessagePage(res, '삭제 실패', '해당 자재 정보가 존재하지 않습니다.');
#         }
#
#         res.redirect('/material/list');
#     });
# });
#
# app.listen(PORT, () => {
#     console.log('=========================================');
#     console.log(` 자재관리 서버가 포트 ${PORT}에서 작동 중입니다.`);
#     console.log('=========================================');
# });
# Out:
# Overwriting server.js

# %% [markdown]
# # 공통 - cloudflare 및 sql 세팅

# %%
# !npm init -y
# Out:
# Wrote to /content/package.json:
#
# {
#   "name": "content",
#   "version": "1.0.0",
#   "main": "server.js",
#   "scripts": {
#     "test": "echo \"Error: no test specified\" && exit 1",
#     "start": "node server.js"
#   },
#   "keywords": [],
#   "author": "",
#   "license": "ISC",
#   "dependencies": {
#     "express": "^5.2.1",
#     "mysql2": "^3.20.0"
#   },
#   "devDependencies": {},
#   "description": ""
# }
#
#
#
# ⠙

# %%
# !npm install express mysql2
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 77 packages in 1s
# ⠇
# ⠇24 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# found 0 vulnerabilities
# ⠇

# %%
# !nohup node server.js > server.log 2>&1 &

# %%
# !tail -n 20 server.log
# Out:
# ...
#  자재관리 서버가 포트 3000에서 작동 중입니다.
# ...
# DB 연결 성공

# %%
# !npm install -g cloudflared
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇
# changed 1 package in 2s
# ⠇

# %%
# !nohup cloudflared tunnel --url http://localhost:3000 > tunnel.log 2>&1 &

# %%
# !tail -n 20 tunnel.log
# Out:
# 2026-03-18T01:50:19Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-03-18T01:50:19Z INF Requesting new quick Tunnel on trycloudflare.com...

# %%
# !grep -o "https://[a-zA-Z0-9.-]*\.trycloudflare.com" tunnel.log |tail -n 1
# Out:
# https://newspaper-keeping-international-response.trycloudflare.com
